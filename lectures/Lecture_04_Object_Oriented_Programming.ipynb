# %% [markdown]
# # Lecture 4: Object Oriented Programming

# %% [markdown]
# How to "read" this lecture notebook
# <details>
# <summary>click to expand</summary>
#
# As you go through this notebook (or any notebook for this class), you will encounter new concepts and python code that implements them -- just like you would see in a textbook. Of course, in a textbook, it's easy to read code and an explanation of what it does and think that you understand it.
# <br />
#
# ### Learn by doing
# But this notebook is different from a textbook because it allows you to not just read the code, but play with it. **You can and should try out changing the code that you see**. In fact, in many places throughout this reading notebook, you will be asked to write your own code to experiment with a concept that was just covered. This is a form of "active reading" and the idea behind it is that we really learn by **doing**.
# <br />
#
# ### Change everything
# But don't feel limited to only change code when I prompt you. This notebook is your learning environment and your playground. I encourage you to try changing and running all the code throughout the notebook and even to **add your own notes and new code blocks**. Adding comments to code to explain what you are testing, experimenting with or trying to do is really helpful to understand what you were thinking when you revisit it later.
# <br />
# ### Make this notebook your own
# Make this notebook your own. Write your questions and thoughts. At the end of every reading notebook, I will ask the same set of questions to try to elicit your questions, reaction and feedback. When we review the reading notebook in class, I encourage you to

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# - Understand and apply the fundamental principles of object-oriented programming (classes, objects, inheritance, encapsulation, polymorphism)
# - Design and implement class hierarchies using inheritance
# - Use state machines to model and implement complex behaviors
# - Create objects that interact with and reference one another
# - Override methods to customize behavior in subclasses
# - Apply OOP concepts to build modular, maintainable code

# %% [markdown]
# # 4.0 Code Preface

# %%
from random import randint

# %% [markdown]
# # 4.1 Classes and Object Orientation

# %% [markdown]
# <img alt="Summer school classes are wild" src="../images/L04_summer_school.png" width="800" style="display:block;">
# <font size=2>Students add some flair to their classes in <i>Summer School (1987)</i>. Not the kind of classes we'll be talking about.</font>
#
# ## What is a class?
#
#
# In Python, we have seen scalar type variables:
# - int, float, bool, None
#
# We have also seen more complex non-scalar types that have their own structure.
# - this includes collections such as List, Dict, Tuples
# - and also other types such as String
#
# What are these more complicated types?
# - They are actually defined by classes
#
# A class is an "idea" -- it is the template for an object. It describes the structure of the object that you create with the class. You can think of a class as a "cookie cutter". We use them to create objects, which you can think of as the "cookie".
#
# <img alt="L04_classes_are_cookie_cutters.png" src="../images/L04_classes_are_cookie_cutters.png" style="display:block;">

# %% [markdown]
# ## Why Classes? Inspired by Struct
#
# A long time ago in a galaxy far far away... programmers realized they needed something more than just regular variables. They wanted a way to group together a bunch of variables that were naturally related.
#
# Suppose we wanted to represent a point in 3D space. We would need to keep track of the three coordinates for the point, the x,y and z coordinates. We could just define them as three variables in our code:
#
# ```C
# x = 2.0
# y = 3.5
# z = 1.3
# ```
# Notice that nowhere in the code is the idea that these three variables are related to the same point. And what if we wanted to represent a whole bunch of points?  Should we do this?
#
# ```C
# x1 = 2.0
# y1 = 3.5
# z1 = 1.3
#
# x2 = 0.5
# y2 = 1.78
# z2 = -2.4
# ```
#
# It starts to get very messy. This is where the idea of a Struct came in.
#
# A Struct (short for structure) is a way of structuring a bunch of related variables together. They don't formally exist in Python, because classes can do what structs can do and a whole lot more. So I'll show you what a struct looks like in the C programming language:
#
# ```C
# struct Point {
#   float x;
#   float y;
#   float z;
# }
# ```
#
# The struct is a definition of a point variable, which holds the three coordinate variables x, y, z "inside of it". If we wanted to make a new point in our C program, we would do it like this:
#
# ```C
# struct Point somePoint;
# somePoint.x = 2.0;
# somePoint.y = 3.5;
# somePonit.z = 1.3;
# ```
# The first line above declares that the variable somePoint is a struct and that the template defined earlier tells us its structure. The next three lines set the values of the x,y,z variables that live "inside of" somePoint.
#
# The idea of structs really helped programmers out with organizing their code better and grouping related variables together.
#
# But what if we had some function that was designed specifically to be used on points. Where should we put that function?
#
# Structs don't allow you to define such a function that "lives inside". But classes do!

# %% [markdown]
# ## From Structs to Classes
#
# Let's imagine that Python allowed us to define a struct and that we had one for a Person. The variables that might live inside this Person struct could include:
# - name, age, height, relationshipStatus
#
# So imagine we had already defined the struct, and we wanted to make a new person in our code. We might do it like this:
#
# ```python
# somePerson = Person() # Use the template definition we're pretending we created
# somePerson.name = "Holly Gennaro"
# somePerson.age = 40
# somePerson.height = 162.5
# somePerson.relationshipStatus = "separated"
# ```
#
# <div class="callout" style="
#   width: 80%;
#   background: rgba(127,127,127,0.15);
#   border: 1px solid rgba(127,127,127,0.3);
#   padding: 10px 30px;
#   margin: 20px;
#   border-radius: 6px;
#   text-align: justify;
#   text-align-last: left;
#   font-size: 11pt;
# ">
#   <span style="
#     font-size: 60pt;
#     line-height: 1;
#     float: left;
#     margin: 0px 0px 0px 0;
#   ">
#
#   </span>
# <img alt="L04_Holly_Gennaro.png" src="../images/L04_Holly_Gennaro.png" style="float:left;height:100px;margin-right:20px">
#   In case, you couldn't tell, I'm using characters from my favorite movie, <b>Die Hard</b>, to illustrate this example. This is a picture of Holly Gennaro, who separated from the hero, John McClane, and moved to LA to work for the Nakatomi Corporation. She used her maiden name, Holly Gennaro, at her new job and it was a point of disagreement between the couple.
#
#   <!-- clearfix -->
#   <div style="clear: both;"></div>
# </div>
#
#
# Even better if we could define a bunch of things at the time of creation:
# ```python
# somePerson = Person("Holly Gennaro", 40, 162.5, "separated")
# ```
#
# Somewhere later in our code, we might want to change the values of the variables inside this person. We could do it in the usual way:
# ```python
# somePerson.relationshipStatus = "married"
# ```
#
# But maybe we want to control how the variables inside can change. For example, when the person "reunites with the hero", we might want to change her relationship status to "married" and also change her name to "Holly McClane" (re-adopting her married last name).  It would be nice if we could just make both changes at the same time using a function:
#
# ```python
# somePerson.reuniteWithHero("Holly McClane")
# ```
# Such a function could set `relationshipStatus="married"` and also change the person's name to the "Holly McClane" (the argument we passed into the function). Because the function only operates on the variables that "live inside of" the person, it should really also "live inside" the person. Structs can't accomodate that, but classes can. And, as we will see, classes can do a lot of other really useful things.

# %% [markdown]
# ## Defining a Class

# %% [markdown]
# A Class definition includes:
# - The **Name** of the class
#   - what you will use to create a new object from that class e.g., Person()
# - **Properties** (or attributes)
#   - the variables that "live inside" the object of that class type e.g., height
# - **Methods**
#   - Functions that "live inside" the object of that class type e.g., reuniteWithHero()
#
# Here's how we would define the class for the example used earlier (you should run this code now!):

# %%
# An example class for a person
class Person():
  def __init__(self, name, age, height, relationshipStatus):
    self.name = name
    self.age = age
    self.height = height
    self.relationshipStatus = relationshipStatus
  
  def reuniteWithHero(self, newName):
    print("reuiniting with hero...")
    self.relationshipStatus = "married"
    self.name=newName

# %% [markdown]
# You might be confused by some things in the definition of the class above. For example, what the heck is this ```__init__()``` method? What is this weird keyword ```self``` doing there? Why do we have all these statements like ```self.x = x```? I'll explain all of this soon, but for now, just focus on the concept that this class is a **cookie cutter** that defines the **properties** (variables that *"live inside it"*) and the **methods** (functions that *"live inside it"*).
#
# We will use this definition to **instantiate** an object of this type.  The word instantiate describes using our *"cookie cutter"* (class) to create a *"cookie"* (object).
#
# We say that ***"somePerson is an instance of the class Person".*** And here's how we can instantiate one:

# %%
somePerson = Person("Holly Gennaro", 40, 162.5, "separated")

# %%
type(somePerson)
# Out:
# __main__.Person

# %% [markdown]
# Now that we've instantiated a new person object called somePerson, we can use it in our code. We can also call its methods:

# %%
print(f"The person's name is {somePerson.name}. Their relationship status is {somePerson.relationshipStatus}.") # I'm using f-strings here to print with a nice format
somePerson.reuniteWithHero("Holly McClane") # use the reuniteWithHero() method
print(f"The person's name is {somePerson.name}. Their relationship status is {somePerson.relationshipStatus}.")
# Out:
# The person's name is Holly Gennaro. Their relationship status is separated.
# reuiniting with hero...
# The person's name is Holly McClane. Their relationship status is married.

# %% [markdown]
# Ok, now let's go back to the definition of the class and try to make sense of what's going on there.

# %% [markdown]
# <!-- Start Exercise 4.1 -->
# <hr/>
# <img src="../images/stop_right_margin.png" align="left">
#
# <font size=3 color="darkred"> In Your Own Words: What is an Object and a Class? </font>
# <div class="inclass_exercise_body" style="padding-left: 130px; width: 85%; text-align: justify;text-align-last: left;">
# What are classes and objects? Why are they useful? Why would we want them?
# </div>

# %% [markdown]
# Classes define traits and behaviors that objects are built from. Objects are instances of classes and contain the actual data.This is useful because code can get messy and this helps organize your code. We can make object more abstract by giving them traits. This also allows us to model entities in a structured and reusable way.

# %% [markdown]
# ENTER YOUR EXPLANATION HERE.

# %% [markdown]
# <hr/>
# <!-- End Exercise 4.1 -->

# %% [markdown]
# # 4.2 Anatomy of a class

# %% [markdown]
# <img alt="Welcome to the party, pal" src="../images/L04_welcome_diehard.png" width="800" style="display:block;">
# <font size=2>"Welcome to the party, pal!" - John McClane <i>Die Hard (1988)</i>.</font>
#
#
# Let's look at the pieces of our class definition one by one. We'll start with the `self` keyword
#
# **<font size=4>The `self` keyword</font>**
#
# <img alt="L04_self_keyword.png" src="../images/L04_self_keyword.png" width="700" style="display:block;">
#
#
# `self` is a special keyword that we only use inside of class definitions. It is a placeholder variable that will hold a reference to the object that we instantiate.  Basically, this reference always points to itself. Let's see this in practice:

# %%
print(somePerson) # The reference that this prints out is the location in memory where the somePerson object is stored.
# Out:
# <__main__.Person object at 0x11895b4d0>

# %% [markdown]
# The output of the above shows that `somePerson` is an object of type `__main__.Person` (that's just the code written above that defines the `Person` class) and that it lives at a particular address in our machine's memory (the value of that address may be different each time you run this notebook).

# %% [markdown]
# **<font size=4>The Constructor (`__init__()`)</font>**
#
# Ok, what's the deal with this weird `__init__()` method?
#
# This is the class **constructor**. It is a special function that is called when we create an object that is an instance of the class.
#
# <img alt="L04_constructor.png" src="../images/L04_constructor.png" width="700" style="display:block;">
#
#
# Notice that we said our constructor method has some arguments that it expects:
#  - name, age, height, relationshipStatus.
#
# When we create `somePerson` with:
# ```python
# somePerson = Person("Holly Gennaro", 40, 162.5, "separated")
# ```
# we are actually calling the `__init__()` constructor.  <font color=blue>When we call any method, we basically pretend that the self argument isn't there. </font>That's why the first argument of `Person()` is the name. Python already knows that you are talking about the somePerson instance when you call a method like `somePerson.reuniteWithHero("Holly McClane")` so it fills in the first argument for you.
# <br>
# <br>
#
# **<font size=4>Storing Things in a Class and the `self.x = x` Pattern</font>**
#
# Let's look at this line of code in the constructor:
# ```python
# self.name = name
# ```
# What is this line in the constructor doing? It's making sure that the variable `name` will be stored as a property of the object we make. Whenever we use `self.x = something` we are saying "I want my object to have this property `x` and it will be equal to `something`".
#
# <div class="callout" style="
#   width: 80%;
#   background: rgba(127,127,127,0.15);
#   border: 1px solid rgba(127,127,127,0.3);
#   padding: 10px 30px;
#   margin: 20px;
#   border-radius: 6px;
#   text-align: justify;
#   text-align-last: left;
#   font-size: 11pt;
# ">
#   <span style="
#     font-size: 60pt;
#     line-height: 1;
#     float: left;
#     margin: 0px 0px 0px 0;
#   ">
#     💡
#   </span>
#
# Remember: Functions have their own <b>local namespaces</b>, which are like <i>scrap paper</i>. Once a function or method is run, all the arguments passed into it and all the variables defined within it will no longer exist or be accessible when the function or method terminates.
#
#
#   <!-- clearfix -->
#   <div style="clear: both;"></div>
# </div>
#
#
# <br />
#
#
# Unlike the temporary variables in the scrap paper of functions or methods, objects *do* live on after you create them (at least until your program is done running), just like variables that we declare in our main program. And **if we want to keep a particular variable in a method around after the method is finished running, we can store it in the object, using the `self.x = x` pattern.**
#
# You can see that the property `name` is stored by the constructor of the class by running the following code:

# %%
somePerson = Person("Holly Gennaro", 40, 162.5, "separated")
print(somePerson.name) # This will print out "Holly Gennaro"
# Out:
# Holly Gennaro

# %% [markdown]
# One reason why this might be confusing is that we have two things called `name` -- the argument `name` that we passed into the constructor and the property `name` that lives in the object.  We didn't have to do it this way. In fact, we could have defined the class in a way that distinguishes them from one another, like this:

# %%
class Person():
  def __init__(self, argName, argAge, argHeight, argRelationshipStatus):
    self.name = argName
    self.age = argAge
    self.height = argHeight
    self.relationshipStatus = argRelationshipStatus
  
  def reuniteWithHero(self, newName):
    print("reuniting with hero...")
    self.relationshipStatus = "married"
    self.name=newName

# %% [markdown]
# When we create a new person object, the result will be the same:

# %%
somePerson = Person("Holly Gennaro", 40, 162.5, "separated")
print(somePerson.name)
# Out:
# Holly Gennaro

# %% [markdown]
# <div class="callout" style="
#   width: 80%;
#   background: rgba(127,127,127,0.15);
#   border: 1px solid rgba(127,127,127,0.3);
#   padding: 10px 30px;
#   margin: 20px;
#   border-radius: 6px;
#   text-align: justify;
#   text-align-last: left;
#   font-size: 11pt;
# ">
#   <span style="
#     font-size: 60pt;
#     line-height: 1;
#     float: left;
#     margin: 0px 0px 0px 0;
#   ">
#     🧠
#   </span>
#
# <font color=blue>**Q**</font>: Dylan, if you could have done it that way from the beginning, why did you use `name` twice and confuse us?
#
# <font color=blue>**A**</font>: Because its common practice to follow this convention (i.e., give the argument the same name as the property) when you define classes.  You will see this convention all the time, so you'll have to get used to it.
#
#   <!-- clearfix -->
#   <div style="clear: both;"></div>
# </div>

# %% [markdown]
# In a real program, we will typically create many instances of a class. For example:

# %%
somePerson1 = Person("Hans Gruber",40,185.4,"single")
somePerson2 = Person("John McClane",33,183,"separated")
print(somePerson1.name)
print(somePerson2.name)
print(somePerson1)
print(somePerson2)
# Out:
# Hans Gruber
# John McClane
# <__main__.Person object at 0x118ab2180>
# <__main__.Person object at 0x118ab0950>

# %% [markdown]
# You can always see the properites and methods inside of an object in python using the command `dir(someObject)`

# %%
dir(somePerson1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'height',
#  'name',
#  'relationshipStatus',
#  'reuniteWithHero']

# %%
dir(somePerson1.__doc__)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# But wait, where did all of these other things come from -- the things that look like `__something__`?  All objects in python get a bunch of properties and methods "for free" when they are created. This is because when we create a new class it always "inherits" from the base class `object` in python where these things are defined. This will make more sense after we have talked about the big ideas of object orientation in the next section.

# %% [markdown]
# <!-- Start Exercise 4.2 -->
#
# <hr/>
# <img src="../images/stop_right_margin.png" align="left">
#
# <font size=3 color="darkred"> Make Your Own Class </font>
# <div class="inclass_exercise_body" style="padding-left: 130px; width: 85%; text-align: justify;text-align-last: left;">
# Make your own class (a type of a thing) based on something tangible in your life. This could be something you carry (a bag), wear (jacket, shoes, etc.), use to get around (a vehicle), or something else entirely. Decide what kind of properties an object of this class should have when it is created. For example, a bag class might have properties to describe the bag's material, color, or number of pockets it has. Give your class at least one method (function that lives inside the class). For example, a bag might have a method to add an item to it.
# </div>

# %%
class Jacket():
    def __init__(self, argColor, argSize, argMaterial, argWashed):
        self.color = argColor
        self.size = argSize
        self.material = argMaterial
        self.wasWashed = argWashed

# %%
Jacket1 = Jacket("Black", "Medium", "Leather", "Not-Washed")

print(Jacket1)
print(Jacket1.color)
# Out:
# <__main__.Jacket object at 0x118ab0e00>
# Black

# %%
def gotwashed(self, newWashed):
    print("Getting washed...")
    self.wasWashed = newWashed
    self.wasWashed = "Washed"

# %%
gotwashed(Jacket1, "Washed")
# Out:
# Getting washed...

# %%
print(Jacket1.wasWashed)
# Out:
# Washed

# %% [markdown]
# <hr/>
# <!-- End Exercise 4.2 -->

# %% [markdown]
# # 4.3 The Big Ideas of Object Orientation

# %% [markdown]
# <img alt="The big idea" src="../images/L04_bigidea_realgenius.jpg" width="700" style="display:block;">
# <font size=2>Chris explains the "Big Idea" in <i>Real Genius (1985)</i>.</font>
#
#
# Classes are much more than just a convenient way to group properties (variables) and methods (functions) together.
#
# Object orientation is a way of thinking and programming in terms of objects in a way that mimics objects in the real world.

# %% [markdown]
# The big ideas of object orientation are:
#  - encapsulation / modularity
#  - inheritance
#  - polymorphism
#  - object interaction
#
# Let's talk about each of these.

# %% [markdown]
# ## Encapsulation: An Ant Simulation

# %% [markdown]
# <img alt="L04_ant.jpg" src="../images/L04_ant.jpg" width="500" style="display:block;">
#
# Suppose we wanted to build some code to simulate an Ant Farm. It will consist of many ants that are going about their business.
#
# At any given moment in the simulation, an ant will have a State (what it is doing) and can "think" for itself to determine whether and how to change its own state.
#
# The states an ant can have are:
# - foraging -- looking for food
# - returningToNest -- carrying food back to the nest
# - sleeping
#
# We can define a very simple "brain" for an ant, which will determine how it changes state. For now, we will assume that:
# - An ant that is foraging will always find food and transition to the state returningToNest on the next turn.
# - An ant will only take one turn to return to the nest and then will transition to the state sleep on the next turn.
# - An ant will sleep for only one turn and then will transition to the state foraging on the next turn.
#
# We can represent this logic with a state diagram:
#
# <img alt="L04_ant_state_diagram.png" src="../images/L04_ant_state_diagram.png" width="400" style="display:block;">
#
# **What is a state machine?** A state machine is a model for describing how something behaves by defining all possible states it can be in and the rules for transitioning between those states. In this case, our ant is a simple state machine that cycles through three states: foraging → returning to nest → sleeping → foraging...
#
# In a **state diagram**, the circles are states and the arrows describe how transitions between states occurs. Sometimes an arrow might include a condition or a probability for a transition to occur. Here, our rule is very simple and transitions are entirely deterministic (not stochastic).
#
# To make it interesting, we will start each ant in a random state. To do this we will have to import a function from the random module to draw a random integer.
#
# Here is a class that implements that:

# %% [markdown]
# Randomness Doesnt Exist. Seed can further determine radomness.

# %%
from random import randint # import the randint function from the random module -- we want to start our ants off in a random state

class Ant():
  def __init__(self,name):
    self.name = name # set the ant's name
    allStatesList = ["foraging","sleeping","returningToNest"] # a list of all states, so we can make a random draw for the initial state
    self.state = allStatesList[randint(0,2)] # draw an initial state at random

  def forage(self):
    self.state = "foraging"
    print(f"{self.name} is foraging.")
  
  def sleep(self):
    self.state = "sleeping"
    print(f"{self.name} is sleeping.")
  
  def returnToNest(self):
    self.state = "returningToNest"
    print(f"{self.name} is returning to the nest with food.")

  def think(self):
    oldState = self.state
    if oldState == "sleeping":
      self.forage()
    elif oldState == "foraging":
      self.returnToNest()
    elif oldState == "returningToNest":
      self.sleep()

# %% [markdown]
# Now we can create some ants and simulate them for some time:

# %%
# Create some ant objects
ant1 = Ant("Dylan")
ant2 = Ant("Kai")
ant3 = Ant("Hyunuk")
ant4 = Ant("Jiho")

# put the ant objects we created into a list -- it will be easier to loop over them this way
antList = [ant1, ant2, ant3, ant4]

for t in range(0,3): # This is the "main loop" of the code. It simulates time passing and what happens for every "tick of the clock" 
  print(f"t={t}")
  for ant in antList: # This loops over all the ants
    ant.think() # tell a given ant to think (call its think() method)

# Because the simulation has a random component to it, you should run this a few times to see how the results change.
# Out:
# t=0
# Dylan is foraging.
# Kai is foraging.
# Hyunuk is returning to the nest with food.
# Jiho is sleeping.
# t=1
# Dylan is returning to the nest with food.
# Kai is returning to the nest with food.
# Hyunuk is sleeping.
# Jiho is foraging.
# t=2
# Dylan is sleeping.
# Kai is sleeping.
# Hyunuk is foraging.
# Jiho is returning to the nest with food.

# %% [markdown]
# While this is a very simple simulation, it captures the first big idea of object-oriented thinking: encapsulation / modularity.
#
# Objects in the our code represent real world objects. They are responsible for handling their internal state. The complexity of how they determine a state transition is **encapsulated** inside their class.  Other parts of the program *don't need to know how they work*. Here, our main program doesn't need to know how the ant thinks, it just calls ```ant.think()```. The logic of how it thinks is handled by the Ant class.
#
# If we later decide we want to change how the brain of an ant works, we don't have to update the main simulation loop in our code. We just have to update the ```think()``` method of the Ant class. This is how modular design works. Each module can be swapped out for an equivalent module without having to change the rest of the program.

# %% [markdown]
# <!-- Start Exercise 4.3 -->
# <hr/>
# <img src="../images/stop_right_margin.png" align="left">
#
# <font size=3 color="darkred"> In Your Own Words: What is encapsulation? </font>
#
# <div class="inclass_exercise_body" style="padding-left: 130px; width: 85%; text-align: justify;text-align-last: left;">
# Explain what encapsulation is all about. Can the idea of encapsulation be extended outside of code? What about for an organization --  let's think of a very small college with three academic departments. What would encapsulation mean? Can a business use the principle of encapsulation? How?
# </div>

# %% [markdown]
# Encapsulation is about hiding complexity and bundling related data and behaviors together into self-contained units. Encapsulation can be extended outside of code like in Businesses and Organizations. Imagining a college with different departments encapsulation would look like the departments having their own curriculum, controls its budget, hires their own teachers, etc. Similaryly businesses have different departments as well.

# %% [markdown]
# <hr/>
# <!-- End Exercise 4.3 -->

# %% [markdown]
# ## Inheritance: A Creature Super Class

# %% [markdown]
# Suppose we wanted to extend our simulation and add other types of creatures to it. We might realize that there is some properties and methods that all creatures ought to have. We could go ahead and make a new class for each creature type and define each class to have these shared properties and methods. However, this would involve repeating identical code in multiple places. What if we later wanted to change some of those shared properties or methods -- we would have to change them in many places in our code.  Fortunately, there is a better way: to use **inheritance**.
#
# Let's illustrate this with an example:

# %%
class Creature():
  def __init__(self,name):
    self.isCreature = True
    self.name = name
  
  def think(self):
    print(f'{self.name} is thinking...')
  
  def speak(self):
    print(f'{self.name} makes a sound.')

# %%
creature = Creature('some creature') # create a new creature
creature.think()
creature.speak()
# Out:
# some creature is thinking...
# some creature makes a sound.

# %% [markdown]
# This defines a new creature class that has a property, `name`, and two methods: `speak()` and `think()`.
#
# The idea is that any creature we create should be based off of the class Creature and "inherit" the properties and methods that Creature has -- even if we don't define them in the class.
#
# Now, whenever we want to make a new type of creature, we will tell it to inherit from Creature like this:

# %%
class Ant(Creature): # notice that Creature is included inside the () after the class name
  def __init__(self,name):
    super().__init__(name) # this is a special way to call the constructor of the super class (the class Ant inherits from)
    allStatesList = ["foraging","sleeping","returningToNest"] # a list of all states, so we can make a random draw for the initial state
    self.state = allStatesList[randint(0,2)] # draw an initial state at random

  def forage(self):
    self.state = "foraging"
    print(f"{self.name} is foraging.")
  
  def sleep(self):
    self.state = "sleeping"
    print(f"{self.name} is sleeping.")
  
  def returnToNest(self):
    self.state = "returningToNest"
    print(f"{self.name} is returning to the nest with food.")

  def think(self):
    oldState = self.state
    if oldState == "sleeping":
      self.forage()
    elif oldState == "foraging":
      self.returnToNest()
    elif oldState == "returningToNest":
      self.sleep()

# %% [markdown]
# We say that:
# - Creature is the super (or parent) class of Ant.
# - Ant is a subclass (or child) of Creature.
#
# Let's look at what inheritance did for us:

# %%
ant1 = Ant("Dylan")
ant1.speak()
ant1.isCreature
# Out:
# Dylan makes a sound.
# True

# %% [markdown]
# Notice that `ant1` had the method `speak()` even though it wasn't defined in the Ant class. That is because Ant "inherited" the method speak from its "super" class. Similarly, `ant1` has the property `isCreature` even though we didn't define it in the class.
#
# You might have noticed that in the constructor for Ant, I didn't set the property of name with `self.name = name`. You also may have noticed that there was a line:
# ```python
# super().__init__(name)
# ```
# The first part of this line `super()` is a special method that will return a reference to the super class. The next part of this line `.__init__(name)` calls the constructor of the super class (Creature) and passes the argument name.

# %% [markdown]
# Inheritance is very powerful because it helps you to avoid repeating code and to build new classes that <font color="blue">conform to the interface of existing classes</font>. In other words, **whatever the parent can do, the child can do**. Changing the behavior of the parent will also change the behavior of the children.

# %% [markdown]
# <!-- Start Exercise 4.4 -->
# <hr/>
# <img src="../images/stop_right_margin.png" align="left">
#
# <font size=3 color="darkred"> Exercise: Make Your Own Base and Child Classes </font>
#
# <div class="inclass_exercise_body" style="padding-left: 130px; width: 85%; text-align: justify;text-align-last: left;">
# Make three classes for something tangible in your life -- a base class and two child classes. The child classes need to be a "more specific type" of the base class. For example, this could be a Vehicle class (base) and Car and Skateboard classes (child). Come up with some properties and methods for each. Which properties and methods are common to all child classes (and therefore belong in the base class) and which belong in the children classes?
# </div>

# %%
# Base Class: Device (something we all use daily)
class Device():
    def __init__(self, brand, model, batteryLevel):
        self.brand = brand
        self.model = model
        self.batteryLevel = batteryLevel
        self.isOn = False
    
    def powerOn(self):
        if not self.isOn:
            self.isOn = True
            print(f"{self.brand} {self.model} is now ON.")
        else:
            print(f"{self.brand} {self.model} is already ON.")
    
    def powerOff(self):
        if self.isOn:
            self.isOn = False
            print(f"{self.brand} {self.model} is now OFF.")
        else:
            print(f"{self.brand} {self.model} is already OFF.")
    
    def checkBattery(self):
        print(f"Battery level: {self.batteryLevel}%")
        if self.batteryLevel < 20:
            print("Warning: Low battery!")

# Child Class 1: Smartphone 
class Smartphone(Device):
    def __init__(self, brand, model, batteryLevel, carrier):
        super().__init__(brand, model, batteryLevel)
        self.carrier = carrier
        self.hasNotifications = False
    
    def makeCall(self, phoneNumber):
        if self.isOn:
            print(f"Calling {phoneNumber} via {self.carrier}...")
        else:
            print("Cannot make call. Device is OFF.")
    
    def sendText(self, message, recipient):
        if self.isOn:
            print(f"Sending text to {recipient}: '{message}'")
        else:
            print("Cannot send text. Device is OFF.")

# Child Class 2: Laptop 
class Laptop(Device):
    def __init__(self, brand, model, batteryLevel, operatingSystem):
        super().__init__(brand, model, batteryLevel)
        self.operatingSystem = operatingSystem
        self.openApplications = []
    
    def openApp(self, appName):
        if self.isOn:
            self.openApplications.append(appName)
            print(f"Opening {appName} on {self.operatingSystem}...")
        else:
            print("Cannot open app. Device is OFF.")
    
    def closeApp(self, appName):
        if appName in self.openApplications:
            self.openApplications.remove(appName)
            print(f"Closing {appName}.")
        else:
            print(f"{appName} is not open.")

# Testing the classes
print("=== Testing Smartphone ===")
myPhone = Smartphone("Apple", "iPhone 15", 85, "Verizon")
myPhone.checkBattery()
myPhone.makeCall("555-1234")  # Won't work - device is off
myPhone.powerOn()
myPhone.makeCall("555-1234")
myPhone.sendText("Hey, how are you?", "Friend")

print("\n=== Testing Laptop ===")
myLaptop = Laptop("Dell", "XPS 13", 45, "Windows 11")
myLaptop.powerOn()
myLaptop.checkBattery()
myLaptop.openApp("VS Code")
myLaptop.openApp("Chrome")
myLaptop.closeApp("VS Code")
myLaptop.powerOff()
# Out:
# === Testing Smartphone ===
# Battery level: 85%
# Cannot make call. Device is OFF.
# Apple iPhone 15 is now ON.
# Calling 555-1234 via Verizon...
# Sending text to Friend: 'Hey, how are you?'
#
# === Testing Laptop ===
# Dell XPS 13 is now ON.
# Battery level: 45%
# Opening VS Code on Windows 11...
# Opening Chrome on Windows 11...
# Closing VS Code.
# Dell XPS 13 is now OFF.

# %% [markdown]
# <hr/>
# <!-- End Exercise 4.4 -->

# %% [markdown]
# ### Class Diagrams

# %% [markdown]
# In fact we can build chains or trees of parent-child relations.  In highly object-oriented code in the real world, complex inheritance structures exist and we have to have a way of keeping track of them. A good way to do this is with a class diagram in Unified Modeling Language (UML).
#
# <img alt="L04_class_diagram.png" src="../images/L04_class_diagram.png" width="500" style="display:block;">
#
# In a **UML Class Diagram**, each class is represented by a box with three sections. The top section holds the name of the class, the middle section lists its properties, and the bottom section lists its methods.
#
# To indicate inheritance, an arrow is drawn pointing from the child class to the parent class.
# <br><br>
# <font size=5>A simple example</font>
#
# ---
#
# Suppose we are running an ecommerce site that sells to all sorts of customers. But we have two special types of customers: Academic Customers and Business Customers. We might like to create subclasses for these two types of customers. Here's what a class diagram might look like for that scenario:
#
# <img alt="L04_class_diagram_example.png" src="../images/L04_class_diagram_example.png" width="500" style="display:block;">
#
# ---
# <br><br>
# <font size=5>A complex example</font>
#
# ---
# Here's the class diagram for a web server
#
# <img alt="L04_class_diagram_example_webserver.png" src="../images/L04_class_diagram_example_webserver.png" style="display:block;">
#
# ---
#
# I bet you can appreciate how important it is to reap the benefits of inheritance and avoid repeating code in a complex example such as this.

# %% [markdown]
# ## Polymorphism: Overriding parent methods

# %% [markdown]
# <img alt="L04_polymorphism.png" src="../images/L04_polymorphism.png" width="500" style="display:block;">
#
# Polymorphism means "many different forms". In object-oriented programming, it refers to the ability for methods to have many forms. When we inherit from a class, we get all of its methods. However, we can choose to **override any of these methods** by *defining the method in the subclass*. This allows a method, such as `speak()` to have "many different forms" -- i.e., to do something different depending on the form that is implemented in the subclass.
#
# In fact, we **overrode** the constructor by defining it in the `Ant` class. We saw that overriding isn't a destructive action. For example, we could still access the super's constructor (and therefore we can still have it do whatever it does when a creature is created) with the help of `super()`.
#
# <div class="callout" style="
#   width: 80%;
#   background: rgba(127,127,127,0.15);
#   border: 1px solid rgba(127,127,127,0.3);
#   padding: 10px 30px;
#   margin: 20px;
#   border-radius: 6px;
#   text-align: justify;
#   text-align-last: left;
#   font-size: 11pt;
# ">
#   <span style="
#     font-size: 60pt;
#     line-height: 1;
#     float: left;
#     margin: 0px 0px 0px 0;
#   ">
#     💡
#   </span>
#
# Overriding a constructor and calling `super().__init__()` is very common. When you subclass a class **you didn’t write**, you often want to customize the constructor but may not know exactly what the parent’s constructor does. The safest approach is to call the parent constructor first, so you preserve its initialization before adding your own.
#
#
#   <!-- clearfix -->
#   <div style="clear: both;"></div>
# </div>
#
#
# Besides the constructor, did we override any other methods when we defined the Ant class?
#
# **YES**, we overrode the `think()` method:

# %%
creature.think()
ant1.think()
# Out:
# some creature is thinking...
# Dylan is sleeping.

# %% [markdown]
# Notice that the `think()` method of Creature always prints out "{name} is thinking". But the `think()` method of our Ant class will handle the transition between the three states and print out "{name} is {state action}."  And, again, if we really wanted to, we could call the super's `think()` instead. The syntax of calling it from outside of the class definition is a bit different:

# %%
super(type(ant1),ant1).think() # Call the super's think()
# note: Most of the time you would use super() from within the class definition rather than from outside
# Out:
# Dylan is thinking...

# %% [markdown]
# **So what's the advantage of overriding (polymorphism)?**
#
# The advantage is that you can write code to handle objects of type Creature and it will magically just work for anything that inherits from Creature. If a subclass of Creature wants to "do things differently" for any of its methods, it takes the responsibility of doing so when it overrides the method. This is another example of *encapsulation / modular design*.

# %% [markdown]
# <!-- Start Exercise 4.5 -->
# <hr/>
# <img src="../images/stop_right_margin.png" align="left">
#
# <font size=3 color="darkred">  Exercise: Make Bees, Spiders, and Ants Speak </font>
# <div class="inclass_exercise_body" style="padding-left: 130px; width: 85%; text-align: justify;text-align-last: left;">
# For this exercise, instead of writing all the code from scratch, I'm going to provide you with some starter code and ask you to modify it. Follow the numbered comments in the code below to accomplish the following:
#
# <br />
#
# 1. Modify the Ant class so that it overrides the `speak()` method. The Ant version of this method should print out `"{self.name} chirps."`
#
# 2. Create a Bee and Spider class that both inherit from Creature. ***You don't have to define a constructor or any other methods*** -- just override the `speak()` method so that a bee object prints out `"{self.name} buzzes."` and a spider object prints out `"{self.name} chitters."`
#
# </div>

# %%
# Define the creature class again here for clarity (its the same as above)
class Creature():
  def __init__(self,name):
    self.isCreature = True
    self.name = name
  
  def think(self):
    print(f'{self.name} is thinking...')
  
  def speak(self):
    print(f'{self.name} makes a sound.')



# 1. Modify the ant class below to override the speak() method. It should print out "{self.name} chirps."
class Ant(Creature): 
  def __init__(self,name):
    super().__init__(name) 
    allStatesList=["foraging","sleeping","returningToNest"] 
    self.state=allStatesList[randint(0,2)]

  def forage(self):
    self.state="foraging"
    print(f"{self.name} is foraging.")
  
  def sleep(self):
    self.state="sleeping"
    print(f"{self.name} is sleeping.")
  
  def returnToNest(self):
    self.state="returningToNest"
    print(f"{self.name} is returning to the nest with food.")

  def think(self):
    oldState=self.state
    if oldState=="sleeping":
      self.forage()
    elif oldState=="foraging":
      self.returnToNest()
    elif oldState=="returningToNest":
      self.sleep()

  def speak(self):
    print(f"{self.name} chirps.")

# 2. Below, define your own Bee class that inherits from Creature and override the speak method so that a bee says "{self.name} buzzes."
class Bee(Creature):
  def speak(self):
    print(f"{self.name} buzzes.")

# 3. Below, define your own Spider class that inherits from Creature and override the speak method so that a spider says "{self.name} chitters."
class Spider(Creature):
  def speak(self):
    print(f"{self.name} chitters.")
  
# Uncomment the code below and ensure that it runs properly.
# Expected output: "Dylan chirps.", "Jon buzzes." and "Sarah chitters."
ant1 = Ant("Dylan")
ant1.speak()

bee1 = Bee("Jon")
bee1.speak()

spider1 = Spider("Sarah")
spider1.speak()
# Out:
# Dylan chirps.
# Jon buzzes.
# Sarah chitters.

# %% [markdown]
# <hr/>
# <!-- End Exercise 4.5 -->

# %% [markdown]
# # 4.4 Objects can interact: A Garden Simulation

# %% [markdown]
# <img alt="Look, a giant ant!" src="../images/L04_giant_ant_honey.png" width="800" style="display:block;">
# <font size=2>The kids befriend a "giant" ant in <i>Honey, I shrunk the kids (1989)</i>.</font>
#
#
# In a program, objects don't live in isolation, but often interact with one another. They often <font color=blue>hold references</font> to one another. An object can even <font color=blue>tell another object what do</font> (by calling its methods) or <font color=blue>react to another object's state</font>.
#
# We'll illustrate this with a simulation of a Garden full of ants and a spider.
# <br><br>
# The classes:
# - **Garden**: A class that will keep track of all the "things" in the garden. It will be responsible for making time tick and telling all living things to think.<br><br>
# - **Creature**: A parent class that will hold a reference to the garden (i.e., all creatures have to live in some garden). It implements `think()`, `speak()` and `die()`.  Though we will override `think()` and `speak()` in subclasses.<br><br>
#  - **Ant**: a subclass of creature that is responsible for doing what ants do -- `forage()`, `returnToNest()`, and `sleep()` and deciding what to do next by implementing `think()`.  We'll use the same state diagram as before. However, the twist is that living ants can be eaten by a spider (and therefore die).<br><BR>
#  - **Spider**: a subclass of creature that is responsible for doing what spiders do -- `hunt()` and `sleep()` and deciding what to do next by implementing `think()`. When hunting, it will be successful 30% of the time and catch and eat an ant. However, if the spider goes 6 turns without eating, it will die.
#
# <br><br>
# Some tricks that we will use:
# - `choice(someList)` to get a random element from a list.
# - `sample(someList, len(someList))` to effectively shuffle the order of a list.
# - `isinstance(someObject, someClass)` to determine if someObject is an instance of someClass.
#
#
# Let's build this step by step, introducing one class at a time.

# %% [markdown]
# ## Step 1: The Garden Class
#
# First, let's create the Garden class. This class will manage the simulation by keeping track of all the things in the garden and advancing time.

# %%
from random import random, sample, choice

class Garden():
  def __init__(self):
    print("Creating garden...")
    self.things = list() # garden stores a list of things --  all the things that "are in the garden" 
    self.clock = 0 # garden keeps track of the "world clock"
  
  # the tick method advances the clock and "makes things happen"
  def tick(self): 
    print(f"t = {self.clock}\n")
    for thing in sample(self.things, len(self.things)): # this line "shuffles" the list so that the order that creatures think is random
      if isinstance(thing, Creature): # if the thing is a creature...
        if thing.alive:# and it is alive
          thing.think() # make the thing "think"
    print("--------------------------")
    self.clock += 1

# %% [markdown]
# ## Step 2: The Creature Base Class
#
# Now let's create the Creature base class. Notice how the constructor accepts a reference to the garden, stores it, and adds itself to the garden's list of things. This is how objects hold references to one another!

# %%
class Creature():
  def __init__(self, garden, name): # when you create any creature, you have to pass a reference to the garden, as well as the name of the creature
    self.alive = True # creatures store whether they are alive (and always start out alive)
    self.name = name # creatures store their own name
    self.garden = garden # creatures store a reference to the garden "where they live"
    self.garden.things.append(self) # When you create a creature, it adds itself to the list of things in the garden
  
  # This is a "stub" method -- we expect it to be overridden in a subclass
  def think(self):
    print(f'{self.name} is thinking...')
  
  # This is another "stub" method -- we expect it to be overridden in a subclass
  def speak(self):
    print(f'{self.name} makes a sound.')
  
  def die(self):
    self.alive = False
    print(f'{self.name} died.')

# %% [markdown]
# Let's test what we have so far. We'll create a garden and add a basic creature to it:

# %%
# Create a garden and a simple creature
garden = Garden()
creature1 = Creature(garden, "Test Creature")

# Run the simulation for a few ticks
for t in range(0, 3):
  garden.tick()
# Out:
# Creating garden...
# t = 0
#
# Test Creature is thinking...
# --------------------------
# t = 1
#
# Test Creature is thinking...
# --------------------------
# t = 2
#
# Test Creature is thinking...
# --------------------------

# %% [markdown]
# ## Step 3: The Ant Class
#
# Now let's add the Ant class. Notice how it inherits from Creature and overrides the `speak()` and `think()` methods to give ants their specific behavior.

# %%
class Ant(Creature): 
  def __init__(self,garden,name):
    print(f"Adding ant {name} to the garden...")
    super().__init__(garden, name) # do whatever creatures do when they are created
    allStatesList = ["foraging", "sleeping", "returningToNest"] 
    self.state = choice(allStatesList) # pick a random state to start in

  def forage(self):
    self.state = "foraging"
    print(f"{self.name} is foraging.")
    self.speak()
  
  def sleep(self):
    self.state = "sleeping"
    print(f"{self.name} is sleeping.")
  
  def returnToNest(self):
    self.state = "returningToNest"
    print(f"{self.name} is returning to the nest with food.")

  # override speak so that ants chirp.
  def speak(self):
    print(f"Ant {self.name} chirps.")

  def think(self):
    oldState = self.state
    if oldState=="sleeping":
      self.forage()
    elif oldState=="foraging":
      self.returnToNest()
    elif oldState=="returningToNest":
      self.sleep()

# %% [markdown]
# Let's test the ants in action:

# %%
# Create a garden with some ants
garden = Garden()
ant1 = Ant(garden,"Kai")
ant2 = Ant(garden,"Hyunuk")
ant3 = Ant(garden,"Jiho")

# Run the simulation
print("\nBegin simulation")
for t in range(0, 5):
  garden.tick()
# Out:
# Creating garden...
# Adding ant Kai to the garden...
# Adding ant Hyunuk to the garden...
# Adding ant Jiho to the garden...
#
# Begin simulation
# t = 0
#
# Jiho is sleeping.
# Kai is foraging.
# Ant Kai chirps.
# Hyunuk is returning to the nest with food.
# --------------------------
# t = 1
#
# Kai is returning to the nest with food.
# Hyunuk is sleeping.
# Jiho is foraging.
# Ant Jiho chirps.
# --------------------------
# t = 2
#
# Kai is sleeping.
# Jiho is returning to the nest with food.
# Hyunuk is foraging.
# Ant Hyunuk chirps.
# --------------------------
# t = 3
#
# Hyunuk is returning to the nest with food.
# Kai is foraging.
# Ant Kai chirps.
# Jiho is sleeping.
# --------------------------
# t = 4
#
# Hyunuk is sleeping.
# Jiho is foraging.
# Ant Jiho chirps.
# Kai is returning to the nest with food.
# --------------------------

# %% [markdown]
# ## Step 4: The Spider Class
#
# Finally, let's add the spider! This is where things get interesting - the spider will hunt ants by interacting with them through the garden's list of creatures. Notice how one object (the spider) can tell another object (an ant) what to do by calling `huntedAnt.die()`.

# %%
class Spider(Creature):
  def __init__(self, garden, name):
    print(f"Adding spider {name} to the garden...")
    super().__init__(garden, name) # do whatever creatures do when they are created.
    allStatesList = ["hunting", "sleeping"] # Spiders only have two states: hunting and sleeping.
    self.state = choice(allStatesList) 
    self.timeSinceLastAte = 0 # spiders keep track of the time since they last ate. If they go too long without eating, they will die.
  
  def hunt(self):
    self.speak() # Let out a predatory roar... or chitter...
    print(f"Spider {self.name} is hunting.")
    if random()>0.3: # the code block below will be executed 30% of the time -- spiders aren't always successful when they hunt
      livingAnts = [thing for thing in self.garden.things if isinstance(thing, Ant) and thing.alive] # get a list of possible prey
      if len(livingAnts)>0: # if the list isn't empty
        huntedAnt = choice(livingAnts) # pick a living ant at random to hunt
        print(f"Spider {self.name} hunted ant {huntedAnt.name}.")
        huntedAnt.die() # tell the hunted ant that it needs to die.
        self.timeSinceLastAte = 0 # reset the time since the spider last ate.

  def sleep(self):
    print(f"Spider {self.name} is sleeping.")
  
  def speak(self):
    print(f"Spider {self.name} chitters.")
  
  # The spider has a similar brain as that ant, but only two states... and the brain handles whether the spider dies from starvation.
  def think(self):
    oldState=self.state
    if oldState=="sleeping":
      self.state = "hunting"
      self.hunt()
    elif oldState=="hunting":
      self.state = "sleeping"
      self.sleep()
    self.timeSinceLastAte += 1
    if self.timeSinceLastAte > 6:
      self.die()

# %% [markdown]
# ## Step 5: Putting It All Together
#
# Now let's run the complete simulation with both ants and a spider. Watch how the spider hunts the ants and how the ants die when caught. The spider will also eventually die if it doesn't catch enough ants!

# %%
garden = Garden()
spider1 = Spider(garden,"Dylan")
ant1 = Ant(garden,"Colton")
ant2 = Ant(garden,"Manny")
ant3 = Ant(garden,"Carlo")

print("\n\nBegin simulation")
for t in range(0,20):
  garden.tick()
# Out:
# Creating garden...
# Adding spider Dylan to the garden...
# Adding ant Colton to the garden...
# Adding ant Manny to the garden...
# Adding ant Carlo to the garden...
#
#
# Begin simulation
# t = 0
#
# Spider Dylan is sleeping.
# Carlo is sleeping.
# Colton is sleeping.
# Manny is returning to the nest with food.
# --------------------------
# t = 1
#
# Carlo is foraging.
# Ant Carlo chirps.
# Colton is foraging.
# Ant Colton chirps.
# Manny is sleeping.
# Spider Dylan chitters.
# Spider Dylan is hunting.
# Spider Dylan hunted ant Carlo.
# Carlo died.
# --------------------------
# t = 2
#
# Manny is foraging.
# Ant Manny chirps.
# Colton is returning to the nest with food.
# Spider Dylan is sleeping.
# --------------------------
# t = 3
#
# Spider Dylan chitters.
# Spider Dylan is hunting.
# Spider Dylan hunted ant Manny.
# Manny died.
# Colton is sleeping.
# --------------------------
# t = 4
#
# Colton is foraging.
# Ant Colton chirps.
# Spider Dylan is sleeping.
# --------------------------
# t = 5
#
# Colton is returning to the nest with food.
# Spider Dylan chitters.
# Spider Dylan is hunting.
# Spider Dylan hunted ant Colton.
# Colton died.
# --------------------------
# t = 6
#
# Spider Dylan is sleeping.
# --------------------------
# t = 7
#
# Spider Dylan chitters.
# Spider Dylan is hunting.
# --------------------------
# t = 8
#
# Spider Dylan is sleeping.
# --------------------------
# t = 9
#
# Spider Dylan chitters.
# Spider Dylan is hunting.
# --------------------------
# t = 10
#
# Spider Dylan is sleeping.
# --------------------------
# t = 11
#
# Spider Dylan chitters.
# Spider Dylan is hunting.
# Dylan died.
# --------------------------
# t = 12
#
# --------------------------
# t = 13
#
# --------------------------
# t = 14
#
# --------------------------
# t = 15
#
# --------------------------
# t = 16
#
# --------------------------
# t = 17
#
# --------------------------
# t = 18
#
# --------------------------
# t = 19
#
# --------------------------

# %%
garden.things.append(Bee)

# %%
garden.things
# Out:
# [<__main__.Spider at 0x118af6e70>,
#  <__main__.Ant at 0x118af7e30>,
#  <__main__.Ant at 0x118af7dd0>,
#  <__main__.Ant at 0x118af4620>,
#  __main__.Bee]

# %%
[[thing.name, thing, thing.alive] for thing in garden.things]
# Out:
# [['Dylan', <__main__.Spider at 0x118af6e70>, False],
#  ['Colton', <__main__.Ant at 0x118af7e30>, False],
#  ['Manny', <__main__.Ant at 0x118af7dd0>, False],
#  ['Carlo', <__main__.Ant at 0x118af4620>, False]]

# %% [markdown]
# # Your Turn: Questions, Reactions, and Feedback
#
#
# Before our next class, think about:
#
# 1. What concepts were new to you? The concept of using classes and objects as a game was new and intriguing
# 2. What do you want more practice with? I want more practice organizing my code and using f strings since I am rusty
# 3. Does object oriented design change the way you think about managing modularity, responsibility and interaction in code (or even organizations)?
# Object-oriented design has fundamentally shifted my perspective on managing complexity in both code and organizations. Makes it more aparent how you can create a whole ecosystem that can interact with each other. Making classes can present clear purpose and responsibility.
#
# 4. Any questions or points of confusion?
# No
#
# **Write your thoughts below:**
#
# *[Your reflections here]*

# %%
# Enhanced Planet Simulation with Daily Summaries and Random Events (Made for fun - using AI)
# Features comprehensive end-of-day reports and random events each day

from random import random, sample, choice, randint

# ======================
# Step 1: The Enhanced Planet Class with Daily Summaries
# ======================

class Planet():
    def __init__(self, name):
        print(f"🌍 Creating planet {name}...")
        self.name = name
        self.inhabitants = list()
        self.clock = 0
        self.resources = 150
        self.major_events = []
    
    def tick(self):
        """Advance time with dramatic storytelling and daily summaries"""
        print(f"\n{'='*70}")
        print(f"🌍 PLANET {self.name} - DAY {self.clock} - DAWN 🌅")
        print(f"{'='*70}")
        print(f"🪨 Resources remaining: {self.resources}")
        
        # Count survivors at start of day
        living_humans = sum(1 for i in self.inhabitants if isinstance(i, Human) and i.alive)
        living_aliens = sum(1 for i in self.inhabitants if isinstance(i, Alien) and i.alive)
        print(f"👤 Humans alive: {living_humans} | 👽 Aliens active: {living_aliens}")
        print(f"{'-'*70}\n")
        
        # RANDOM EVENT at the start of each day
        self.randomDailyEvent()
        
        # Shuffle the order so inhabitants act randomly
        for inhabitant in sample(self.inhabitants, len(self.inhabitants)):
            if isinstance(inhabitant, Inhabitant):
                if inhabitant.alive:
                    inhabitant.think()
        
        # END OF DAY SUMMARY
        self.dailySummary()
        
        # Story checkpoints
        self.checkStoryEvents()
        
        print(f"\n{'-'*70}")
        self.clock += 1
    
    def randomDailyEvent(self):
        """Random events that affect the simulation each day"""
        print(f"\n{'🎲'*35}")
        print(f"🎲 RANDOM EVENT 🎲")
        print(f"{'🎲'*35}")
        
        event_roll = random()
        
        if event_roll < 0.15:  # 15% chance - Resource windfall
            amount = randint(20, 40)
            self.resources += amount
            print(f"🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!")
            print(f"   +{amount} resources added to planet (Total: {self.resources})")
            
        elif event_roll < 0.30:  # 15% chance - Energy boost for humans
            living_humans = [i for i in self.inhabitants if isinstance(i, Human) and i.alive]
            if living_humans:
                boost = randint(15, 30)
                for human in living_humans:
                    human.energy = min(100, human.energy + boost)
                print(f"☀️ SOLAR FLARE! Humans feel energized by cosmic radiation!")
                print(f"   All humans gained +{boost} energy!")
            else:
                print(f"🌫️ Nothing special happens today...")
                
        elif event_roll < 0.40:  # 10% chance - Alien gets hungry
            living_aliens = [i for i in self.inhabitants if isinstance(i, Alien) and i.alive]
            if living_aliens:
                hungry_alien = choice(living_aliens)
                print(f"😈 BLOODLUST! {hungry_alien.species} {hungry_alien.name} feels extra aggressive!")
                print(f"   The alien's hunt success rate increases this turn!")
                hungry_alien.hunt_success_rate = 0.70  # Temporary boost
            else:
                print(f"🌫️ Nothing special happens today...")
                
        elif event_roll < 0.50:  # 10% chance - Resource drain
            drain = randint(10, 25)
            self.resources = max(0, self.resources - drain)
            print(f"🌪️ DUST STORM! The harsh environment depletes resources!")
            print(f"   -{drain} resources lost (Remaining: {self.resources})")
            
        elif event_roll < 0.60:  # 10% chance - Humans find shelter
            living_humans = [i for i in self.inhabitants if isinstance(i, Human) and i.alive]
            if living_humans:
                lucky_human = choice(living_humans)
                recovery = randint(20, 35)
                lucky_human.energy = min(100, lucky_human.energy + recovery)
                print(f"🏠 SAFE HAVEN! {lucky_human.name} discovers a protective shelter!")
                print(f"   {lucky_human.name} recovers +{recovery} energy!")
            else:
                print(f"🌫️ Nothing special happens today...")
                
        else:  # 40% chance - Nothing special
            print(f"🌫️ A calm day... for now. The inhabitants carry on with caution.")
        
        print(f"{'='*70}\n")
    
    def dailySummary(self):
        """Comprehensive end-of-day summary for all entities"""
        print(f"\n{'📋'*35}")
        print(f"📋 END OF DAY {self.clock} - SUMMARY REPORT 📋")
        print(f"{'📋'*35}\n")
        
        # HUMAN SUMMARY
        living_humans = [i for i in self.inhabitants if isinstance(i, Human) and i.alive]
        dead_humans = [i for i in self.inhabitants if isinstance(i, Human) and not i.alive]
        
        print(f"👤 HUMAN EXPEDITION STATUS:")
        print(f"   Survivors: {len(living_humans)}")
        if living_humans:
            print(f"\n   🟢 ACTIVE PERSONNEL:")
            for human in living_humans:
                energy_status = "🔋 FULL" if human.energy > 70 else "⚠️ LOW" if human.energy > 30 else "🚨 CRITICAL"
                print(f"      • {human.role} {human.name}")
                print(f"        Energy: {human.energy}/100 {energy_status} | Resources: {human.resources}")
                print(f"        State: {human.state.upper()} | Discoveries: {human.discoveries}")
        
        if dead_humans:
            print(f"\n   💀 CASUALTIES:")
            for human in dead_humans:
                print(f"      • {human.role} {human.name} - Survived {human.days_survived} days")
        
        # ALIEN SUMMARY
        living_aliens = [i for i in self.inhabitants if isinstance(i, Alien) and i.alive]
        dead_aliens = [i for i in self.inhabitants if isinstance(i, Alien) and not i.alive]
        
        print(f"\n👽 ALIEN FORCES STATUS:")
        print(f"   Active: {len(living_aliens)}")
        if living_aliens:
            print(f"\n   🔴 HOSTILE ENTITIES:")
            for alien in living_aliens:
                hunger_status = "🟢 FED" if alien.timeSinceLastHunt < 4 else "🟡 HUNGRY" if alien.timeSinceLastHunt < 8 else "🔴 STARVING"
                print(f"      • {alien.species} {alien.name}")
                print(f"        Energy: {alien.energy}/100 | Resources: {alien.resources}")
                print(f"        State: {alien.state.upper()} | Kills: {alien.hunts} | {hunger_status}")
                print(f"        Days since last hunt: {alien.timeSinceLastHunt}")
        
        if dead_aliens:
            print(f"\n   ✅ ELIMINATED THREATS:")
            for alien in dead_aliens:
                print(f"      • {alien.species} {alien.name} - Killed {alien.hunts} humans")
        
        # PLANET RESOURCES
        resource_status = "🟢 ABUNDANT" if self.resources > 80 else "🟡 MODERATE" if self.resources > 30 else "🔴 SCARCE"
        print(f"\n🪨 PLANET RESOURCES: {self.resources} {resource_status}")
        
        print(f"\n{'='*70}")
    
    def checkStoryEvents(self):
        """Check for major story milestones"""
        living_humans = [i for i in self.inhabitants if isinstance(i, Human) and i.alive]
        living_aliens = [i for i in self.inhabitants if isinstance(i, Alien) and i.alive]
        
        # Critical events
        if len(living_humans) == 1 and len([i for i in self.inhabitants if isinstance(i, Human)]) > 1:
            survivor = living_humans[0]
            print(f"\n⚠️ {'='*60}")
            print(f"⚠️  CRITICAL: {survivor.name} is the LAST HUMAN SURVIVOR!")
            print(f"⚠️ {'='*60}")
            
        if len(living_humans) == 0 and self.clock > 5:
            print(f"\n💀 {'='*60}")
            print(f"💀 GAME OVER: All humans have perished. The aliens have won.")
            print(f"💀 {'='*60}")
            
        if len(living_aliens) == 0 and self.clock > 5:
            print(f"\n🎉 {'='*60}")
            print(f"🎉 VICTORY: All aliens eliminated! Humanity survives!")
            print(f"🎉 {'='*60}")
    
    def addResource(self, amount):
        """Add resources with feedback"""
        self.resources += amount
        print(f"   🌱 Planet regenerated {amount} resources (Total: {self.resources})")
    
    def consumeResource(self, amount):
        """Remove resources with scarcity warnings"""
        if self.resources >= amount:
            self.resources -= amount
            if self.resources < 30:
                print(f"   ⚠️  WARNING: Resources critically low ({self.resources} remaining)!")
            return True
        else:
            print(f"   ❌ CRISIS: No resources available on planet {self.name}!")
            return False

# ======================
# Step 2: Enhanced Inhabitant Base Class
# ======================

class Inhabitant():
    def __init__(self, planet, name):
        self.alive = True
        self.name = name
        self.planet = planet
        self.planet.inhabitants.append(self)
        self.energy = 100
        self.resources = 0
        self.days_survived = 0
    
    def think(self):
        """Default thinking behavior"""
        print(f'{self.name} is thinking...')
    
    def speak(self):
        """Default speaking behavior"""
        print(f'{self.name} makes a sound.')
    
    def die(self, cause="unknown causes"):
        """Enhanced death with cause tracking"""
        self.alive = False
        print(f'\n💀 {'='*60}')
        print(f'💀💀💀 {self.name} has DIED from {cause}!')
        print(f'💀     Survived for {self.days_survived} days')
        print(f'💀 {'='*60}\n')
    
    def consumeEnergy(self, amount):
        """Use energy with exhaustion warnings"""
        self.energy -= amount
        if self.energy <= 20 and self.energy > 0:
            print(f"   😰 {self.name} is exhausted (Energy: {self.energy})")
        if self.energy <= 0:
            print(f'   💀 {self.name} collapsed from exhaustion!')
            self.die("exhaustion")

# ======================
# Step 3: Enhanced Human Class
# ======================

class Human(Inhabitant):
    def __init__(self, planet, name, role):
        print(f"👤 Human {name} ({role}) has landed on planet {planet.name}...")
        super().__init__(planet, name)
        self.role = role
        
        allStatesList = ["exploring", "gathering", "resting"]
        self.state = choice(allStatesList)
        self.discoveries = 0
        self.close_calls = 0
    
    def explore(self):
        """Explore with dramatic discovery moments"""
        self.state = "exploring"
        print(f"🔍 {self.role} {self.name} ventures into unknown territory...")
        
        if random() > 0.5:
            self.discoveries += 1
            discoveries_list = [
                "ancient alien artifacts",
                "a hidden water source",
                "edible plant life",
                "a mysterious energy signature",
                "evidence of previous civilizations"
            ]
            discovery = choice(discoveries_list)
            print(f"   ✨ DISCOVERY! {self.name} found {discovery}! (Total discoveries: {self.discoveries})")
            self.speak()
        
        self.consumeEnergy(12)
    
    def gather(self):
        """Gather resources with success variability"""
        self.state = "gathering"
        print(f"⛏️  {self.role} {self.name} is gathering vital resources...")
        
        if self.planet.consumeResource(8):
            amount = randint(8, 15)
            self.resources += amount
            print(f"   ✅ {self.name} gathered {amount} resources (Personal: {self.resources})")
        
        self.consumeEnergy(15)
    
    def rest(self):
        """Rest with recovery details"""
        self.state = "resting"
        print(f"😴 {self.role} {self.name} takes shelter to rest...")
        recovery = randint(25, 40)
        self.energy += recovery
        if self.energy > 100:
            self.energy = 100
        print(f"   ⚡ {self.name} recovered {recovery} energy (Current: {self.energy})")
    
    def speak(self):
        """Contextual human dialogue"""
        context_dialogue = {
            "exploring": ["This planet is fascinating!", "I sense something ahead...", "Stay alert, everyone."],
            "gathering": ["These resources are critical!", "We need to stockpile supplies.", "This will help us survive."],
            "resting": ["We need to regroup.", "Tomorrow we continue.", "Rest while we can."]
        }
        dialogue = choice(context_dialogue.get(self.state, ["We can do this."]))
        print(f"   💬 {self.name}: '{dialogue}'")
    
    def think(self):
        """Enhanced decision-making with survival priority"""
        self.days_survived += 1
        oldState = self.state
        
        if self.energy < 25:
            self.rest()
        elif self.energy < 50 and oldState == "gathering":
            self.rest()
        elif oldState == "resting":
            self.explore()
        elif oldState == "exploring":
            self.gather()
        elif oldState == "gathering":
            if random() > 0.6:
                self.rest()
            else:
                self.explore()

# ======================
# Step 4: Enhanced Alien Class with DRAMATIC KILLS
# ======================

class Alien(Inhabitant):
    def __init__(self, planet, name, species):
        print(f"👽 Alien {name} of the {species} species has arrived on planet {planet.name}...")
        super().__init__(planet, name)
        
        self.species = species
        allStatesList = ["hunting", "regenerating"]
        self.state = choice(allStatesList)
        self.timeSinceLastHunt = 0
        self.hunts = 0
        self.hunt_success_rate = 0.35
    
    def hunt(self):
        """DRAMATIC hunting sequence with clear kill announcements"""
        self.state = "hunting"
        print(f"\n{'🔥'*35}")
        print(f"🎯 {self.species} {self.name} BEGINS THE HUNT!")
        print(f"{'🔥'*35}")
        self.speak()
        
        if random() < self.hunt_success_rate:
            livingHumans = [
                inhabitant for inhabitant in self.planet.inhabitants 
                if isinstance(inhabitant, Human) and inhabitant.alive
            ]
            
            if len(livingHumans) > 0:
                target = choice(livingHumans)
                
                # DRAMATIC KILL SEQUENCE
                print(f"\n{'⚔️ '*25}")
                print(f"🚨 ALIEN ATTACK IN PROGRESS! 🚨")
                print(f"{'⚔️ '*25}")
                print(f"👽 {self.species} {self.name} has spotted {target.role} {target.name}!")
                print(f"⚡ The alien moves with terrifying speed...")
                print(f"😱 {target.name} tries to escape but it's too late!")
                print(f"\n{'💥'*25}")
                print(f"🔴 {self.species} {self.name} has KILLED {target.role} {target.name}! 🔴")
                print(f"{'💥'*25}\n")
                
                stolen = target.resources
                self.resources += stolen
                if stolen > 0:
                    print(f"💰 The alien loots {stolen} resources from the fallen human...")
                
                target.die(f"alien attack by {self.species} {self.name}")
                
                self.timeSinceLastHunt = 0
                self.hunts += 1
                self.energy += 50
                
                print(f"📊 {self.name}'s Stats: Hunts: {self.hunts} | Energy: {self.energy} | Resources: {self.resources}")
                print(f"{'='*70}\n")
                
                # Reset hunt success rate after special event
                self.hunt_success_rate = 0.35
            else:
                print(f"🔍 {self.name} searches but finds no human prey...")
                print(f"   The hunt continues...\n")
        else:
            print(f"   ❌ The hunt was unsuccessful.")
            print(f"   {self.name} returns empty-handed...\n")
        
        self.consumeEnergy(20)
        self.timeSinceLastHunt += 1
    
    def regenerate(self):
        """Aliens regenerate the planet"""
        self.state = "regenerating"
        print(f"🌱 {self.species} {self.name} channels energy to regenerate the planet...")
        
        amount = randint(12, 20)
        self.planet.addResource(amount)
        self.energy += 25
        if self.energy > 100:
            self.energy = 100
        print(f"   ⚡ {self.name} recovers energy (Current: {self.energy})")
    
    def speak(self):
        """Menacing alien sounds"""
        alien_sounds = [
            "ZZZRRRK! ZZZRRRK!",
            "🔴 Bleebloop... HUNT MODE ENGAGED! 🔴",
            "⚡ SKREEEEEE! ⚡",
            "Vwoorp... vwoorp... ATTACK!"
        ]
        print(f"   👽 {self.species} {self.name}: '{choice(alien_sounds)}'")
    
    def think(self):
        """Enhanced alien AI with aggression"""
        self.days_survived += 1
        oldState = self.state
        
        if self.energy < 30:
            self.regenerate()
        elif self.timeSinceLastHunt > 10:
            print(f"   💀 {self.name} is starving! Days since last hunt: {self.timeSinceLastHunt}")
            if self.timeSinceLastHunt > 12:
                self.die("starvation")
                return
        elif oldState == "regenerating":
            self.hunt()
        elif oldState == "hunting":
            if self.energy > 50 and random() < 0.4:
                self.hunt()
            else:
                self.regenerate()

# ======================
# Step 5: EPIC STORY SIMULATION WITH DAILY SUMMARIES
# ======================

def runEpicSimulation():
    """Run the full planetary colonization story with comprehensive daily reports"""
    
    print("\n" + "="*70)
    print("🚀 PLANETARY COLONIZATION MISSION: EARTH-2 🚀")
    print("="*70)
    print("\n📖 STORY BRIEFING:")
    print("A human expedition has landed on Earth-2, a planet with")
    print("mysterious alien life forms. The humans must survive and")
    print("establish a colony while hostile aliens hunt them...")
    print("\nEach day brings new challenges and random events!")
    print("="*70 + "\n")
    
    input("Press ENTER to begin the simulation...")
    
    # Create the planet
    earth = Planet("Earth-2")
    
    # Add humans with roles
    human1 = Human(earth, "Commander Sarah Chen", "Commander")
    human2 = Human(earth, "Dr. Marcus Wells", "Chief Scientist")
    human3 = Human(earth, "Engineer Priya Patel", "Lead Engineer")
    human4 = Human(earth, "Pilot James Rodriguez", "Pilot")
    human5 = Human(earth, "Medic Aisha Okonkwo", "Medical Officer")
    
    # Add aliens with species names
    alien1 = Alien(earth, "Xarthon", "Zorgian Hunter")
    alien2 = Alien(earth, "Klaatu", "Mysteron Stalker")
    
    print("\n\n🌍 BEGIN PLANETARY SURVIVAL SIMULATION 🌍\n")
    
    # Run simulation for 40 days
    max_days = 40
    for day in range(0, max_days):
        earth.tick()
        
        # Check for game over conditions
        living_humans = sum(1 for i in earth.inhabitants if isinstance(i, Human) and i.alive)
        living_aliens = sum(1 for i in earth.inhabitants if isinstance(i, Alien) and i.alive)
        
        if living_humans == 0:
            print("\n" + "="*70)
            print("💀 MISSION FAILED: ALL HUMANS ELIMINATED 💀")
            print("="*70)
            break
        
        if living_aliens == 0:
            print("\n" + "="*70)
            print("🎉 MISSION SUCCESS: ALIENS DEFEATED! 🎉")
            print("="*70)
            break
        
        # Pause every 3 days for dramatic effect
        if (day + 1) % 3 == 0 and day < max_days - 1:
            input(f"\n⏸️  Day {day + 1} complete. Press ENTER to continue...\n")
    
    # Final statistics
    print("\n" + "="*70)
    print("📊 FINAL MISSION REPORT 📊")
    print("="*70)
    
    alive_count = sum(1 for i in earth.inhabitants if i.alive)
    total_count = len(earth.inhabitants)
    
    print(f"\n🌍 Planet: {earth.name}")
    print(f"⏰ Mission Duration: {earth.clock} days")
    print(f"🪨 Resources Remaining: {earth.resources}")
    print(f"👥 Survivors: {alive_count}/{total_count}")
    
    print("\n" + "-"*70)
    print("👤 HUMAN EXPEDITION - FINAL STATUS")
    print("-"*70)
    for inhabitant in earth.inhabitants:
        if isinstance(inhabitant, Human):
            status = "✅ SURVIVED" if inhabitant.alive else "💀 KIA"
            print(f"{status} | {inhabitant.role} {inhabitant.name}")
            print(f"        Days Survived: {inhabitant.days_survived} | Energy: {inhabitant.energy}")
            print(f"        Resources: {inhabitant.resources} | Discoveries: {inhabitant.discoveries}")
    
    print("\n" + "-"*70)
    print("👽 ALIEN FORCES - FINAL STATUS")
    print("-"*70)
    for inhabitant in earth.inhabitants:
        if isinstance(inhabitant, Alien):
            status = "✅ ACTIVE" if inhabitant.alive else "💀 ELIMINATED"
            print(f"{status} | {inhabitant.species} {inhabitant.name}")
            print(f"        Days Active: {inhabitant.days_survived} | Energy: {inhabitant.energy}")
            print(f"        Resources: {inhabitant.resources} | Confirmed Kills: {inhabitant.hunts}")
    
    print("\n" + "="*70)
    print("END OF MISSION REPORT")
    print("="*70 + "\n")

# Run the epic simulation
runEpicSimulation()
# Out:
# ======================================================================
# 🚀 PLANETARY COLONIZATION MISSION: EARTH-2 🚀
# ======================================================================
#
# 📖 STORY BRIEFING:
# A human expedition has landed on Earth-2, a planet with
# mysterious alien life forms. The humans must survive and
# establish a colony while hostile aliens hunt them...
#
# Each day brings new challenges and random events!
# ======================================================================
#
# 🌍 Creating planet Earth-2...
# 👤 Human Commander Sarah Chen (Commander) has landed on planet Earth-2...
# 👤 Human Dr. Marcus Wells (Chief Scientist) has landed on planet Earth-2...
# 👤 Human Engineer Priya Patel (Lead Engineer) has landed on planet Earth-2...
# 👤 Human Pilot James Rodriguez (Pilot) has landed on planet Earth-2...
# 👤 Human Medic Aisha Okonkwo (Medical Officer) has landed on planet Earth-2...
# 👽 Alien Xarthon of the Zorgian Hunter species has arrived on planet Earth-2...
# 👽 Alien Klaatu of the Mysteron Stalker species has arrived on planet Earth-2...
#
#
# 🌍 BEGIN PLANETARY SURVIVAL SIMULATION 🌍
#
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 0 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 150
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# ☀️ SOLAR FLARE! Humans feel energized by cosmic radiation!
#    All humans gained +30 energy!
# ======================================================================
#
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
#    ✨ DISCOVERY! Engineer Priya Patel found a hidden water source! (Total discoveries: 1)
#    💬 Engineer Priya Patel: 'Stay alert, everyone.'
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
#    ✨ DISCOVERY! Pilot James Rodriguez found ancient alien artifacts! (Total discoveries: 1)
#    💬 Pilot James Rodriguez: 'Stay alert, everyone.'
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 😴 Medical Officer Medic Aisha Okonkwo takes shelter to rest...
#    ⚡ Medic Aisha Okonkwo recovered 26 energy (Current: 100)
# ⛏️  Chief Scientist Dr. Marcus Wells is gathering vital resources...
#    ✅ Dr. Marcus Wells gathered 10 resources (Personal: 10)
# 🔍 Commander Commander Sarah Chen ventures into unknown territory...
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 0 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 5
#
#    🟢 ACTIVE PERSONNEL:
#       • Commander Commander Sarah Chen
#         Energy: 88/100 🔋 FULL | Resources: 0
#         State: EXPLORING | Discoveries: 0
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 85/100 🔋 FULL | Resources: 10
#         State: GATHERING | Discoveries: 0
#       • Lead Engineer Engineer Priya Patel
#         Energy: 88/100 🔋 FULL | Resources: 0
#         State: EXPLORING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 88/100 🔋 FULL | Resources: 0
#         State: EXPLORING | Discoveries: 1
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 100/100 🔋 FULL | Resources: 0
#         State: RESTING | Discoveries: 0
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 80/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 1
#       • Mysteron Stalker Klaatu
#         Energy: 80/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 142 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 1 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 142
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 8 resources (Personal: 8)
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 13 resources (Total: 147)
#    ⚡ Xarthon recovers energy (Current: 100)
# ⛏️  Commander Commander Sarah Chen is gathering vital resources...
#    ✅ Commander Sarah Chen gathered 12 resources (Personal: 12)
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 10 resources (Personal: 10)
# 🔍 Medical Officer Medic Aisha Okonkwo ventures into unknown territory...
#    ✨ DISCOVERY! Medic Aisha Okonkwo found evidence of previous civilizations! (Total discoveries: 1)
#    💬 Medic Aisha Okonkwo: 'I sense something ahead...'
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 🔍 Chief Scientist Dr. Marcus Wells ventures into unknown territory...
#    ✨ DISCOVERY! Dr. Marcus Wells found evidence of previous civilizations! (Total discoveries: 1)
#    💬 Dr. Marcus Wells: 'I sense something ahead...'
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 1 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 5
#
#    🟢 ACTIVE PERSONNEL:
#       • Commander Commander Sarah Chen
#         Energy: 73/100 🔋 FULL | Resources: 12
#         State: GATHERING | Discoveries: 0
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 73/100 🔋 FULL | Resources: 10
#         State: EXPLORING | Discoveries: 1
#       • Lead Engineer Engineer Priya Patel
#         Energy: 73/100 🔋 FULL | Resources: 10
#         State: GATHERING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 73/100 🔋 FULL | Resources: 8
#         State: GATHERING | Discoveries: 1
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 88/100 🔋 FULL | Resources: 0
#         State: EXPLORING | Discoveries: 1
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 100/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟢 FED
#         Days since last hunt: 1
#       • Mysteron Stalker Klaatu
#         Energy: 60/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 2
#
# 🪨 PLANET RESOURCES: 131 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 2 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 131
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# 🔍 Commander Commander Sarah Chen ventures into unknown territory...
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 15 resources (Total: 146)
#    ⚡ Klaatu recovers energy (Current: 85)
# ⛏️  Chief Scientist Dr. Marcus Wells is gathering vital resources...
#    ✅ Dr. Marcus Wells gathered 11 resources (Personal: 21)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '⚡ SKREEEEEE! ⚡'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# ⛏️  Medical Officer Medic Aisha Okonkwo is gathering vital resources...
#    ✅ Medic Aisha Okonkwo gathered 12 resources (Personal: 12)
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 2 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 5
#
#    🟢 ACTIVE PERSONNEL:
#       • Commander Commander Sarah Chen
#         Energy: 61/100 ⚠️ LOW | Resources: 12
#         State: EXPLORING | Discoveries: 0
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 58/100 ⚠️ LOW | Resources: 21
#         State: GATHERING | Discoveries: 1
#       • Lead Engineer Engineer Priya Patel
#         Energy: 61/100 ⚠️ LOW | Resources: 10
#         State: EXPLORING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 61/100 ⚠️ LOW | Resources: 8
#         State: EXPLORING | Discoveries: 1
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 73/100 🔋 FULL | Resources: 12
#         State: GATHERING | Discoveries: 1
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 80/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 2
#       • Mysteron Stalker Klaatu
#         Energy: 85/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟢 FED
#         Days since last hunt: 2
#
# 🪨 PLANET RESOURCES: 130 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 3 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 130
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +30 resources added to planet (Total: 160)
# ======================================================================
#
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 10 resources (Personal: 18)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '⚡ SKREEEEEE! ⚡'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 11 resources (Personal: 21)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 😴 Medical Officer Medic Aisha Okonkwo takes shelter to rest...
#    ⚡ Medic Aisha Okonkwo recovered 27 energy (Current: 100)
# ⛏️  Commander Commander Sarah Chen is gathering vital resources...
#    ✅ Commander Sarah Chen gathered 13 resources (Personal: 25)
# 🔍 Chief Scientist Dr. Marcus Wells ventures into unknown territory...
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 3 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 5
#
#    🟢 ACTIVE PERSONNEL:
#       • Commander Commander Sarah Chen
#         Energy: 46/100 ⚠️ LOW | Resources: 25
#         State: GATHERING | Discoveries: 0
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 46/100 ⚠️ LOW | Resources: 21
#         State: EXPLORING | Discoveries: 1
#       • Lead Engineer Engineer Priya Patel
#         Energy: 46/100 ⚠️ LOW | Resources: 21
#         State: GATHERING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 46/100 ⚠️ LOW | Resources: 18
#         State: GATHERING | Discoveries: 1
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 100/100 🔋 FULL | Resources: 12
#         State: RESTING | Discoveries: 1
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 60/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 3
#       • Mysteron Stalker Klaatu
#         Energy: 65/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟢 FED
#         Days since last hunt: 3
#
# 🪨 PLANET RESOURCES: 136 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 4 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 136
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +33 resources added to planet (Total: 169)
# ======================================================================
#
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 15 resources (Total: 184)
#    ⚡ Xarthon recovers energy (Current: 85)
# ⛏️  Chief Scientist Dr. Marcus Wells is gathering vital resources...
#    ✅ Dr. Marcus Wells gathered 12 resources (Personal: 33)
# 🔍 Medical Officer Medic Aisha Okonkwo ventures into unknown territory...
# 😴 Pilot Pilot James Rodriguez takes shelter to rest...
#    ⚡ Pilot James Rodriguez recovered 32 energy (Current: 78)
# 😴 Commander Commander Sarah Chen takes shelter to rest...
#    ⚡ Commander Sarah Chen recovered 31 energy (Current: 77)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 😴 Lead Engineer Engineer Priya Patel takes shelter to rest...
#    ⚡ Engineer Priya Patel recovered 39 energy (Current: 85)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 4 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 5
#
#    🟢 ACTIVE PERSONNEL:
#       • Commander Commander Sarah Chen
#         Energy: 77/100 🔋 FULL | Resources: 25
#         State: RESTING | Discoveries: 0
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 31/100 ⚠️ LOW | Resources: 33
#         State: GATHERING | Discoveries: 1
#       • Lead Engineer Engineer Priya Patel
#         Energy: 85/100 🔋 FULL | Resources: 21
#         State: RESTING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 78/100 🔋 FULL | Resources: 18
#         State: RESTING | Discoveries: 1
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 88/100 🔋 FULL | Resources: 12
#         State: EXPLORING | Discoveries: 1
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 85/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟢 FED
#         Days since last hunt: 3
#       • Mysteron Stalker Klaatu
#         Energy: 45/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 4
#
# 🪨 PLANET RESOURCES: 176 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 5 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 176
# 👤 Humans alive: 5 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +26 resources added to planet (Total: 202)
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '⚡ SKREEEEEE! ⚡'
#
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 🚨 ALIEN ATTACK IN PROGRESS! 🚨
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 👽 Zorgian Hunter Xarthon has spotted Commander Commander Sarah Chen!
# ⚡ The alien moves with terrifying speed...
# 😱 Commander Sarah Chen tries to escape but it's too late!
#
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
# 🔴 Zorgian Hunter Xarthon has KILLED Commander Commander Sarah Chen! 🔴
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
#
# 💰 The alien loots 25 resources from the fallen human...
#
# 💀 ============================================================
# 💀💀💀 Commander Sarah Chen has DIED from alien attack by Zorgian Hunter Xarthon!
# 💀     Survived for 5 days
# 💀 ============================================================
#
# 📊 Xarthon's Stats: Hunts: 1 | Energy: 135 | Resources: 25
# ======================================================================
#
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 18 resources (Total: 220)
#    ⚡ Klaatu recovers energy (Current: 70)
# ⛏️  Medical Officer Medic Aisha Okonkwo is gathering vital resources...
#    ✅ Medic Aisha Okonkwo gathered 13 resources (Personal: 25)
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
# 😴 Chief Scientist Dr. Marcus Wells takes shelter to rest...
#    ⚡ Dr. Marcus Wells recovered 25 energy (Current: 56)
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
#    ✨ DISCOVERY! Pilot James Rodriguez found ancient alien artifacts! (Total discoveries: 2)
#    💬 Pilot James Rodriguez: 'This planet is fascinating!'
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 5 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 4
#
#    🟢 ACTIVE PERSONNEL:
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 56/100 ⚠️ LOW | Resources: 33
#         State: RESTING | Discoveries: 1
#       • Lead Engineer Engineer Priya Patel
#         Energy: 73/100 🔋 FULL | Resources: 21
#         State: EXPLORING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 66/100 ⚠️ LOW | Resources: 18
#         State: EXPLORING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 73/100 🔋 FULL | Resources: 25
#         State: GATHERING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 115/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟢 FED
#         Days since last hunt: 1
#       • Mysteron Stalker Klaatu
#         Energy: 70/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 4
#
# 🪨 PLANET RESOURCES: 212 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 6 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 212
# 👤 Humans alive: 4 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 10 resources (Personal: 28)
# 🔍 Medical Officer Medic Aisha Okonkwo ventures into unknown territory...
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# 🔍 Chief Scientist Dr. Marcus Wells ventures into unknown territory...
#    ✨ DISCOVERY! Dr. Marcus Wells found ancient alien artifacts! (Total discoveries: 2)
#    💬 Dr. Marcus Wells: 'Stay alert, everyone.'
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 9 resources (Personal: 30)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 6 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 4
#
#    🟢 ACTIVE PERSONNEL:
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 44/100 ⚠️ LOW | Resources: 33
#         State: EXPLORING | Discoveries: 2
#       • Lead Engineer Engineer Priya Patel
#         Energy: 58/100 ⚠️ LOW | Resources: 30
#         State: GATHERING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 51/100 ⚠️ LOW | Resources: 28
#         State: GATHERING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 61/100 ⚠️ LOW | Resources: 25
#         State: EXPLORING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 95/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟢 FED
#         Days since last hunt: 2
#       • Mysteron Stalker Klaatu
#         Energy: 50/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 5
#
# 🪨 PLANET RESOURCES: 196 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 7 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 196
# 👤 Humans alive: 4 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🏠 SAFE HAVEN! Medic Aisha Okonkwo discovers a protective shelter!
#    Medic Aisha Okonkwo recovers +25 energy!
# ======================================================================
#
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 13 resources (Total: 209)
#    ⚡ Xarthon recovers energy (Current: 100)
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 17 resources (Total: 226)
#    ⚡ Klaatu recovers energy (Current: 75)
# 😴 Lead Engineer Engineer Priya Patel takes shelter to rest...
#    ⚡ Engineer Priya Patel recovered 36 energy (Current: 94)
# ⛏️  Chief Scientist Dr. Marcus Wells is gathering vital resources...
#    ✅ Dr. Marcus Wells gathered 9 resources (Personal: 42)
# ⛏️  Medical Officer Medic Aisha Okonkwo is gathering vital resources...
#    ✅ Medic Aisha Okonkwo gathered 14 resources (Personal: 39)
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 7 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 4
#
#    🟢 ACTIVE PERSONNEL:
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 29/100 🚨 CRITICAL | Resources: 42
#         State: GATHERING | Discoveries: 2
#       • Lead Engineer Engineer Priya Patel
#         Energy: 94/100 🔋 FULL | Resources: 30
#         State: RESTING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 39/100 ⚠️ LOW | Resources: 28
#         State: EXPLORING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 71/100 🔋 FULL | Resources: 39
#         State: GATHERING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 100/100 | Resources: 25
#         State: REGENERATING | Kills: 1 | 🟢 FED
#         Days since last hunt: 2
#       • Mysteron Stalker Klaatu
#         Energy: 75/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 5
#
# 🪨 PLANET RESOURCES: 210 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 8 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 210
# 👤 Humans alive: 4 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +21 resources added to planet (Total: 231)
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: '⚡ SKREEEEEE! ⚡'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 15 resources (Personal: 43)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# 😴 Chief Scientist Dr. Marcus Wells takes shelter to rest...
#    ⚡ Dr. Marcus Wells recovered 34 energy (Current: 63)
# 😴 Medical Officer Medic Aisha Okonkwo takes shelter to rest...
#    ⚡ Medic Aisha Okonkwo recovered 37 energy (Current: 100)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 8 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 4
#
#    🟢 ACTIVE PERSONNEL:
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 63/100 ⚠️ LOW | Resources: 42
#         State: RESTING | Discoveries: 2
#       • Lead Engineer Engineer Priya Patel
#         Energy: 82/100 🔋 FULL | Resources: 30
#         State: EXPLORING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 24/100 🚨 CRITICAL | Resources: 43
#         State: GATHERING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 100/100 🔋 FULL | Resources: 39
#         State: RESTING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 80/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟢 FED
#         Days since last hunt: 3
#       • Mysteron Stalker Klaatu
#         Energy: 55/100 | Resources: 0
#         State: HUNTING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 6
#
# 🪨 PLANET RESOURCES: 223 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 9 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 223
# 👤 Humans alive: 4 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# ☀️ SOLAR FLARE! Humans feel energized by cosmic radiation!
#    All humans gained +30 energy!
# ======================================================================
#
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 13 resources (Total: 236)
#    ⚡ Klaatu recovers energy (Current: 80)
# 🔍 Chief Scientist Dr. Marcus Wells ventures into unknown territory...
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 11 resources (Personal: 41)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '⚡ SKREEEEEE! ⚡'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# 😴 Pilot Pilot James Rodriguez takes shelter to rest...
#    ⚡ Pilot James Rodriguez recovered 39 energy (Current: 93)
# 🔍 Medical Officer Medic Aisha Okonkwo ventures into unknown territory...
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 9 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 4
#
#    🟢 ACTIVE PERSONNEL:
#       • Chief Scientist Dr. Marcus Wells
#         Energy: 81/100 🔋 FULL | Resources: 42
#         State: EXPLORING | Discoveries: 2
#       • Lead Engineer Engineer Priya Patel
#         Energy: 85/100 🔋 FULL | Resources: 41
#         State: GATHERING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 93/100 🔋 FULL | Resources: 43
#         State: RESTING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 88/100 🔋 FULL | Resources: 39
#         State: EXPLORING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 60/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟡 HUNGRY
#         Days since last hunt: 4
#       • Mysteron Stalker Klaatu
#         Energy: 80/100 | Resources: 0
#         State: REGENERATING | Kills: 0 | 🟡 HUNGRY
#         Days since last hunt: 6
#
# 🪨 PLANET RESOURCES: 228 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 10 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 228
# 👤 Humans alive: 4 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +23 resources added to planet (Total: 251)
# ======================================================================
#
# ⛏️  Medical Officer Medic Aisha Okonkwo is gathering vital resources...
#    ✅ Medic Aisha Okonkwo gathered 10 resources (Personal: 49)
# 😴 Lead Engineer Engineer Priya Patel takes shelter to rest...
#    ⚡ Engineer Priya Patel recovered 34 energy (Current: 100)
# ⛏️  Chief Scientist Dr. Marcus Wells is gathering vital resources...
#    ✅ Dr. Marcus Wells gathered 12 resources (Personal: 54)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 🚨 ALIEN ATTACK IN PROGRESS! 🚨
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 👽 Mysteron Stalker Klaatu has spotted Chief Scientist Dr. Marcus Wells!
# ⚡ The alien moves with terrifying speed...
# 😱 Dr. Marcus Wells tries to escape but it's too late!
#
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
# 🔴 Mysteron Stalker Klaatu has KILLED Chief Scientist Dr. Marcus Wells! 🔴
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
#
# 💰 The alien loots 54 resources from the fallen human...
#
# 💀 ============================================================
# 💀💀💀 Dr. Marcus Wells has DIED from alien attack by Mysteron Stalker Klaatu!
# 💀     Survived for 11 days
# 💀 ============================================================
#
# 📊 Klaatu's Stats: Hunts: 1 | Energy: 130 | Resources: 54
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 10 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 3
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 100/100 🔋 FULL | Resources: 41
#         State: RESTING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 81/100 🔋 FULL | Resources: 43
#         State: EXPLORING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 73/100 🔋 FULL | Resources: 49
#         State: GATHERING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 40/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟡 HUNGRY
#         Days since last hunt: 5
#       • Mysteron Stalker Klaatu
#         Energy: 110/100 | Resources: 54
#         State: HUNTING | Kills: 1 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 235 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 11 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 235
# 👤 Humans alive: 3 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 14 resources (Total: 249)
#    ⚡ Klaatu recovers energy (Current: 100)
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 18 resources (Total: 267)
#    ⚡ Xarthon recovers energy (Current: 65)
# 🔍 Medical Officer Medic Aisha Okonkwo ventures into unknown territory...
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 9 resources (Personal: 52)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 11 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 3
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 88/100 🔋 FULL | Resources: 41
#         State: EXPLORING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 66/100 ⚠️ LOW | Resources: 52
#         State: GATHERING | Discoveries: 2
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 61/100 ⚠️ LOW | Resources: 49
#         State: EXPLORING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 65/100 | Resources: 25
#         State: REGENERATING | Kills: 1 | 🟡 HUNGRY
#         Days since last hunt: 5
#       • Mysteron Stalker Klaatu
#         Energy: 100/100 | Resources: 54
#         State: REGENERATING | Kills: 1 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 259 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 12 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 259
# 👤 Humans alive: 3 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 11 resources (Personal: 52)
# ⛏️  Medical Officer Medic Aisha Okonkwo is gathering vital resources...
#    ✅ Medic Aisha Okonkwo gathered 12 resources (Personal: 61)
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: 'ZZZRRRK! ZZZRRRK!'
#    ❌ The hunt was unsuccessful.
#    Klaatu returns empty-handed...
#
# 🔍 Pilot Pilot James Rodriguez ventures into unknown territory...
#    ✨ DISCOVERY! Pilot James Rodriguez found edible plant life! (Total discoveries: 3)
#    💬 Pilot James Rodriguez: 'This planet is fascinating!'
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 12 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 3
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 73/100 🔋 FULL | Resources: 52
#         State: GATHERING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 54/100 ⚠️ LOW | Resources: 52
#         State: EXPLORING | Discoveries: 3
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 46/100 ⚠️ LOW | Resources: 61
#         State: GATHERING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 45/100 | Resources: 25
#         State: HUNTING | Kills: 1 | 🟡 HUNGRY
#         Days since last hunt: 6
#       • Mysteron Stalker Klaatu
#         Energy: 80/100 | Resources: 54
#         State: HUNTING | Kills: 1 | 🟢 FED
#         Days since last hunt: 2
#
# 🪨 PLANET RESOURCES: 243 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 13 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 243
# 👤 Humans alive: 3 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 19 resources (Total: 262)
#    ⚡ Klaatu recovers energy (Current: 100)
# 😴 Medical Officer Medic Aisha Okonkwo takes shelter to rest...
#    ⚡ Medic Aisha Okonkwo recovered 33 energy (Current: 79)
# ⛏️  Pilot Pilot James Rodriguez is gathering vital resources...
#    ✅ Pilot James Rodriguez gathered 9 resources (Personal: 61)
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 17 resources (Total: 271)
#    ⚡ Xarthon recovers energy (Current: 70)
# 😴 Lead Engineer Engineer Priya Patel takes shelter to rest...
#    ⚡ Engineer Priya Patel recovered 38 energy (Current: 100)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 13 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 3
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 100/100 🔋 FULL | Resources: 52
#         State: RESTING | Discoveries: 1
#       • Pilot Pilot James Rodriguez
#         Energy: 39/100 ⚠️ LOW | Resources: 61
#         State: GATHERING | Discoveries: 3
#       • Medical Officer Medic Aisha Okonkwo
#         Energy: 79/100 🔋 FULL | Resources: 61
#         State: RESTING | Discoveries: 1
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 70/100 | Resources: 25
#         State: REGENERATING | Kills: 1 | 🟡 HUNGRY
#         Days since last hunt: 6
#       • Mysteron Stalker Klaatu
#         Energy: 100/100 | Resources: 54
#         State: REGENERATING | Kills: 1 | 🟢 FED
#         Days since last hunt: 2
#
# 🪨 PLANET RESOURCES: 271 🟢 ABUNDANT
#
# ======================================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 14 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 271
# 👤 Humans alive: 3 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌫️ A calm day... for now. The inhabitants carry on with caution.
# ======================================================================
#
# 😴 Pilot Pilot James Rodriguez takes shelter to rest...
#    ⚡ Pilot James Rodriguez recovered 40 energy (Current: 79)
# 🔍 Lead Engineer Engineer Priya Patel ventures into unknown territory...
#    ✨ DISCOVERY! Engineer Priya Patel found edible plant life! (Total discoveries: 2)
#    💬 Engineer Priya Patel: 'I sense something ahead...'
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: '⚡ SKREEEEEE! ⚡'
#
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 🚨 ALIEN ATTACK IN PROGRESS! 🚨
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 👽 Zorgian Hunter Xarthon has spotted Medical Officer Medic Aisha Okonkwo!
# ⚡ The alien moves with terrifying speed...
# 😱 Medic Aisha Okonkwo tries to escape but it's too late!
#
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
# 🔴 Zorgian Hunter Xarthon has KILLED Medical Officer Medic Aisha Okonkwo! 🔴
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
#
# 💰 The alien loots 61 resources from the fallen human...
#
# 💀 ============================================================
# 💀💀💀 Medic Aisha Okonkwo has DIED from alien attack by Zorgian Hunter Xarthon!
# 💀     Survived for 14 days
# 💀 ============================================================
#
# 📊 Xarthon's Stats: Hunts: 2 | Energy: 120 | Resources: 86
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: 'Vwoorp... vwoorp... ATTACK!'
#
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 🚨 ALIEN ATTACK IN PROGRESS! 🚨
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 👽 Mysteron Stalker Klaatu has spotted Pilot Pilot James Rodriguez!
# ⚡ The alien moves with terrifying speed...
# 😱 Pilot James Rodriguez tries to escape but it's too late!
#
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
# 🔴 Mysteron Stalker Klaatu has KILLED Pilot Pilot James Rodriguez! 🔴
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
#
# 💰 The alien loots 61 resources from the fallen human...
#
# 💀 ============================================================
# 💀💀💀 Pilot James Rodriguez has DIED from alien attack by Mysteron Stalker Klaatu!
# 💀     Survived for 15 days
# 💀 ============================================================
#
# 📊 Klaatu's Stats: Hunts: 2 | Energy: 150 | Resources: 115
# ======================================================================
#
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 14 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 1
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 88/100 🔋 FULL | Resources: 52
#         State: EXPLORING | Discoveries: 2
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#       • Pilot Pilot James Rodriguez - Survived 15 days
#       • Medical Officer Medic Aisha Okonkwo - Survived 14 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 100/100 | Resources: 86
#         State: HUNTING | Kills: 2 | 🟢 FED
#         Days since last hunt: 1
#       • Mysteron Stalker Klaatu
#         Energy: 130/100 | Resources: 115
#         State: HUNTING | Kills: 2 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 271 🟢 ABUNDANT
#
# ======================================================================
#
# ⚠️ ============================================================
# ⚠️  CRITICAL: Engineer Priya Patel is the LAST HUMAN SURVIVOR!
# ⚠️ ============================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 15 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 271
# 👤 Humans alive: 1 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🌟 WINDFALL! A meteor carrying rare minerals crashes nearby!
#    +20 resources added to planet (Total: 291)
# ======================================================================
#
# 🌱 Mysteron Stalker Klaatu channels energy to regenerate the planet...
#    🌱 Planet regenerated 18 resources (Total: 309)
#    ⚡ Klaatu recovers energy (Current: 100)
# 🌱 Zorgian Hunter Xarthon channels energy to regenerate the planet...
#    🌱 Planet regenerated 18 resources (Total: 327)
#    ⚡ Xarthon recovers energy (Current: 100)
# ⛏️  Lead Engineer Engineer Priya Patel is gathering vital resources...
#    ✅ Engineer Priya Patel gathered 12 resources (Personal: 64)
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 15 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 1
#
#    🟢 ACTIVE PERSONNEL:
#       • Lead Engineer Engineer Priya Patel
#         Energy: 73/100 🔋 FULL | Resources: 64
#         State: GATHERING | Discoveries: 2
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#       • Pilot Pilot James Rodriguez - Survived 15 days
#       • Medical Officer Medic Aisha Okonkwo - Survived 14 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 100/100 | Resources: 86
#         State: REGENERATING | Kills: 2 | 🟢 FED
#         Days since last hunt: 1
#       • Mysteron Stalker Klaatu
#         Energy: 100/100 | Resources: 115
#         State: REGENERATING | Kills: 2 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 319 🟢 ABUNDANT
#
# ======================================================================
#
# ⚠️ ============================================================
# ⚠️  CRITICAL: Engineer Priya Patel is the LAST HUMAN SURVIVOR!
# ⚠️ ============================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 🌍 PLANET Earth-2 - DAY 16 - DAWN 🌅
# ======================================================================
# 🪨 Resources remaining: 319
# 👤 Humans alive: 1 | 👽 Aliens active: 2
# ----------------------------------------------------------------------
#
#
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 🎲 RANDOM EVENT 🎲
# 🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲🎲
# 😈 BLOODLUST! Mysteron Stalker Klaatu feels extra aggressive!
#    The alien's hunt success rate increases this turn!
# ======================================================================
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Zorgian Hunter Xarthon BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Zorgian Hunter Xarthon: 'Vwoorp... vwoorp... ATTACK!'
#    ❌ The hunt was unsuccessful.
#    Xarthon returns empty-handed...
#
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
# 🎯 Mysteron Stalker Klaatu BEGINS THE HUNT!
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
#    👽 Mysteron Stalker Klaatu: '🔴 Bleebloop... HUNT MODE ENGAGED! 🔴'
#
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 🚨 ALIEN ATTACK IN PROGRESS! 🚨
# ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️ ⚔️
# 👽 Mysteron Stalker Klaatu has spotted Lead Engineer Engineer Priya Patel!
# ⚡ The alien moves with terrifying speed...
# 😱 Engineer Priya Patel tries to escape but it's too late!
#
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
# 🔴 Mysteron Stalker Klaatu has KILLED Lead Engineer Engineer Priya Patel! 🔴
# 💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥💥
#
# 💰 The alien loots 64 resources from the fallen human...
#
# 💀 ============================================================
# 💀💀💀 Engineer Priya Patel has DIED from alien attack by Mysteron Stalker Klaatu!
# 💀     Survived for 16 days
# 💀 ============================================================
#
# 📊 Klaatu's Stats: Hunts: 3 | Energy: 150 | Resources: 179
# ======================================================================
#
#
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
# 📋 END OF DAY 16 - SUMMARY REPORT 📋
# 📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋📋
#
# 👤 HUMAN EXPEDITION STATUS:
#    Survivors: 0
#
#    💀 CASUALTIES:
#       • Commander Commander Sarah Chen - Survived 5 days
#       • Chief Scientist Dr. Marcus Wells - Survived 11 days
#       • Lead Engineer Engineer Priya Patel - Survived 16 days
#       • Pilot Pilot James Rodriguez - Survived 15 days
#       • Medical Officer Medic Aisha Okonkwo - Survived 14 days
#
# 👽 ALIEN FORCES STATUS:
#    Active: 2
#
#    🔴 HOSTILE ENTITIES:
#       • Zorgian Hunter Xarthon
#         Energy: 80/100 | Resources: 86
#         State: HUNTING | Kills: 2 | 🟢 FED
#         Days since last hunt: 2
#       • Mysteron Stalker Klaatu
#         Energy: 130/100 | Resources: 179
#         State: HUNTING | Kills: 3 | 🟢 FED
#         Days since last hunt: 1
#
# 🪨 PLANET RESOURCES: 319 🟢 ABUNDANT
#
# ======================================================================
#
# 💀 ============================================================
# 💀 GAME OVER: All humans have perished. The aliens have won.
# 💀 ============================================================
#
# ----------------------------------------------------------------------
#
# ======================================================================
# 💀 MISSION FAILED: ALL HUMANS ELIMINATED 💀
# ======================================================================
#
# ======================================================================
# 📊 FINAL MISSION REPORT 📊
# ======================================================================
#
# 🌍 Planet: Earth-2
# ⏰ Mission Duration: 17 days
# 🪨 Resources Remaining: 319
# 👥 Survivors: 2/7
#
# ----------------------------------------------------------------------
# 👤 HUMAN EXPEDITION - FINAL STATUS
# ----------------------------------------------------------------------
# 💀 KIA | Commander Commander Sarah Chen
#         Days Survived: 5 | Energy: 77
#         Resources: 25 | Discoveries: 0
# 💀 KIA | Chief Scientist Dr. Marcus Wells
#         Days Survived: 11 | Energy: 66
#         Resources: 54 | Discoveries: 2
# 💀 KIA | Lead Engineer Engineer Priya Patel
#         Days Survived: 16 | Energy: 73
#         Resources: 64 | Discoveries: 2
# 💀 KIA | Pilot Pilot James Rodriguez
#         Days Survived: 15 | Energy: 79
#         Resources: 61 | Discoveries: 3
# 💀 KIA | Medical Officer Medic Aisha Okonkwo
#         Days Survived: 14 | Energy: 79
#         Resources: 61 | Discoveries: 1
#
# ----------------------------------------------------------------------
# 👽 ALIEN FORCES - FINAL STATUS
# ----------------------------------------------------------------------
# ✅ ACTIVE | Zorgian Hunter Xarthon
#         Days Active: 17 | Energy: 80
#         Resources: 86 | Confirmed Kills: 2
# ✅ ACTIVE | Mysteron Stalker Klaatu
#         Days Active: 17 | Energy: 130
#         Resources: 179 | Confirmed Kills: 3
#
# ======================================================================
# END OF MISSION REPORT
# ======================================================================
